# %%
#kidney annotation
import os
os.chdir('/lustre/scratch126/cellgen/team297/bs16/current_projects/kidney_glomTI_response/code')
import anndata as ad
import scanpy as sc
import os
import pandas as pd
import numpy as np
import useful_functions as uf
import scvi
import scvelo as scv
sc.set_figure_params(figsize=(6, 6), dpi = 150, fontsize = 10)
import sys
print(sys.executable)
import matplotlib as mpl
import matplotlib.pyplot as plt
import celltypist as ctp

from datetime import datetime
print(datetime.now(tz=None))
# Out:
# Global seed set to 0
# /home/jovyan/my-conda-envs/myenv/lib/python3.9/site-packages/pytorch_lightning/utilities/warnings.py:53: LightningDeprecationWarning: pytorch_lightning.utilities.warnings.rank_zero_deprecation has been deprecated in v1.6 and will be removed in v1.8. Use the equivalent function from the pytorch_lightning.utilities.rank_zero module instead.
#   new_rank_zero_deprecation(
# /home/jovyan/my-conda-envs/myenv/lib/python3.9/site-packages/pytorch_lightning/utilities/warnings.py:58: LightningDeprecationWarning: The `pytorch_lightning.loggers.base.rank_zero_experiment` is deprecated in v1.7 and will be removed in v1.9. Please use `pytorch_lightning.loggers.logger.rank_zero_experiment` instead.
#   return new_rank_zero_deprecation(*args, **kwargs)
# /home/jovyan/my-conda-envs/myenv/bin/python
# 2023-07-16 11:10:52.033442

# %%
import warnings
warnings.filterwarnings('ignore')
#this will hide the awful pandas deprec warnings that are currently plaguing scanpy

#now print versions
print(sc.__version__)
print(ad.__version__)
print(pd.__version__)
print(scvi.__version__)
print(scv.__version__)
os.chdir('/lustre/scratch126/cellgen/team297/bs16/current_projects/kidney_glomTI_response')
# Out:
# 1.9.1
# 0.8.0
# 1.5.1
# 0.19.0
# 0.2.5

# %%
os.chdir('/lustre/scratch126/cellgen/team297/bs16/current_projects/kidney_glomTI_response')
adata = sc.read_h5ad("./data/annotated/perfusion_sortseq.h5ad")

# %%
adata.uns['IC_status_colors'] = ['purple', 'darkblue', 'grey']
adata.uns['stimulation_colors'] = ['red', 'grey']
adata.uns['compartment_colors'] = ['orange', 'blude']

# %%
sc.set_figure_params(figsize=(5,5), dpi = 150, fontsize = 10, vector_friendly = False)
sc.pl.umap(adata, color = ['IC_status', 'cell_type', 'stimulation', 'compartment'], add_outline = False, save = 'sort_seq_umaps.pdf')
# Out:
# WARNING: The following color value found in adata.uns['compartment_colors'] is not valid: 'blude'. Default colors will be used instead.
# WARNING: saving figure to file figures/umapsort_seq_umaps.pdf

# %%
#get the monocyte response signature
monocyte_response = np.array(pd.read_csv('data/da_results/perfusion/response_signatures/classical_monocyte_tf_refined_geneset.csv', index_col = 0).x)
GEC_response = np.array(pd.read_csv('data/da_results/perfusion/response_signatures/GEC_tf_refined_geneset.csv', index_col = 0).x)
NK1_response = np.array(pd.read_csv('data/da_results/perfusion/response_signatures/NK1_tf_refined_geneset.csv', index_col = 0).x)

# %%
sc.tl.score_genes(adata, gene_list =monocyte_response, score_name = 'monocyte_response' )
sc.tl.score_genes(adata, gene_list =GEC_response, score_name = 'GEC_response' )
sc.tl.score_genes(adata, gene_list =NK1_response, score_name = 'NK1_response' )
# Out:
# WARNING: genes are not in var_names and ignored: ['ADORA2A', 'CCL4']
# WARNING: genes are not in var_names and ignored: ['U2AF1']
# WARNING: genes are not in var_names and ignored: ['CCL4']

# %%
sc.pl.umap(adata, color = ['monocyte_response', 'GEC_response', "NK1_response"], cmap = 'magma')

# %%
sc.pl.matrixplot(adata[adata.obs['cell_type'].isin(['classical_monocyte', 'NK1'])], 
            var_names = ['monocyte_response', 'NK1_response'], groupby = 'cell_type_stim', 
                standard_scale = 'var', swap_axes = True, save = 'sortseq_response_vs_IC.pdf')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [9], line 1
# ----> 1 sc.pl.matrixplot(adata[adata.obs['cell_type'].isin(['classical_monocyte', 'NK1'])],
#       2             var_names = ['monocyte_response', 'NK1_response'], groupby = 'cell_type_stim',
#       3                 standard_scale = 'var', swap_axes = True, save = 'sortseq_response_vs_IC.pdf')
#
# File ~/my-conda-envs/myenv/lib/python3.9/site-packages/scanpy/plotting/_matrixplot.py:378, in matrixplot(adata, var_names, groupby, use_raw, log, num_categories, figsize, dendrogram, title, cmap, colorbar_title, gene_symbols, var_group_positions, var_group_labels, var_group_rotation, layer, standard_scale, values_df, swap_axes, show, save, ax, return_fig, vmin, vmax, vcenter, norm, **kwds)
#     279 @_doc_params(
#     280     show_save_ax=doc_show_save_ax,
#     281     common_plot_args=doc_common_plot_args,
#    (...)
#     313     **kwds,
#     314 ) -> Union[MatrixPlot, dict, None]:
#     315     """\
#     316     Creates a heatmap of the mean expression values per group of each var_names.
#     317
#    (...)
#     375         axes_dict = mp.get_axes()
#     376     """
# --> 378     mp = MatrixPlot(
#     379         adata,
#     380         var_names,
#     381         groupby=groupby,
#     382         use_raw=use_raw,
#     383         log=log,
#     384         num_categories=num_categories,
#     385         standard_scale=standard_scale,
#     386         title=title,
#     387         figsize=figsize,
#     388         gene_symbols=gene_symbols,
#     389         var_group_positions=var_group_positions,
#     390         var_group_labels=var_group_labels,
#     391         var_group_rotation=var_group_rotation,
#     392         layer=layer,
#     393         values_df=values_df,
#     394         ax=ax,
#     395         vmin=vmin,
#     396         vmax=vmax,
#     397         vcenter=vcenter,
#     398         norm=norm,
#     399         **kwds,
#     400     )
#     402     if dendrogram:
#     403         mp.add_dendrogram(dendrogram_key=dendrogram)
#
# File ~/my-conda-envs/myenv/lib/python3.9/site-packages/scanpy/plotting/_matrixplot.py:118, in MatrixPlot.__init__(self, adata, var_names, groupby, use_raw, log, num_categories, categories_order, title, figsize, gene_symbols, var_group_positions, var_group_labels, var_group_rotation, layer, standard_scale, ax, values_df, vmin, vmax, vcenter, norm, **kwds)
#      93 def __init__(
#      94     self,
#      95     adata: AnnData,
#    (...)
#     116     **kwds,
#     117 ):
# --> 118     BasePlot.__init__(
#     119         self,
#     120         adata,
#     121         var_names,
#     122         groupby,
#     123         use_raw=use_raw,
#     124         log=log,
#     125         num_categories=num_categories,
#     126         categories_order=categories_order,
#     127         title=title,
#     128         figsize=figsize,
#     129         gene_symbols=gene_symbols,
#     130         var_group_positions=var_group_positions,
#     131         var_group_labels=var_group_labels,
#     132         var_group_rotation=var_group_rotation,
#     133         layer=layer,
#     134         ax=ax,
#     135         vmin=vmin,
#     136         vmax=vmax,
#     137         vcenter=vcenter,
#     138         norm=norm,
#     139         **kwds,
#     140     )
#     142     if values_df is None:
#     143         # compute mean value
#     144         values_df = self.obs_tidy.groupby(level=0).mean()
#
# File ~/my-conda-envs/myenv/lib/python3.9/site-packages/scanpy/plotting/_baseplot_class.py:111, in BasePlot.__init__(self, adata, var_names, groupby, use_raw, log, num_categories, categories_order, title, figsize, gene_symbols, var_group_positions, var_group_labels, var_group_rotation, layer, ax, vmin, vmax, vcenter, norm, **kwds)
#     103 self.has_var_groups = (
#     104     True
#     105     if var_group_positions is not None and len(var_group_positions) > 0
#     106     else False
#     107 )
#     109 self._update_var_groups()
# --> 111 self.categories, self.obs_tidy = _prepare_dataframe(
#     112     adata,
#     113     self.var_names,
#     114     groupby,
#     115     use_raw,
#     116     log,
#     117     num_categories,
#     118     layer=layer,
#     119     gene_symbols=gene_symbols,
#     120 )
#     121 if len(self.categories) > self.MAX_NUM_CATEGORIES:
#     122     warn(
#     123         f"Over {self.MAX_NUM_CATEGORIES} categories found. "
#     124         "Plot would be very large."
#     125     )
#
# File ~/my-conda-envs/myenv/lib/python3.9/site-packages/scanpy/plotting/_anndata.py:1910, in _prepare_dataframe(adata, var_names, groupby, use_raw, log, num_categories, layer, gene_symbols)
#    1908     else:
#    1909         msg = ''
# -> 1910     raise ValueError(
#    1911         'groupby has to be a valid observation. '
#    1912         f'Given {group}, is not in observations: {adata.obs_keys()}' + msg
#    1913     )
#    1914 if group in adata.obs.keys() and group == adata.obs.index.name:
#    1915     raise ValueError(
#    1916         f'Given group {group} is both and index and a column level, '
#    1917         'which is ambiguous.'
#    1918     )
#
# ValueError: groupby has to be a valid observation. Given cell_type_stim, is not in observations: ['well', 'sorted_cell', 'plate', 'IC_status', 'kidney', 'compartment', 'stimulation', 'n_genes_by_counts', 'log1p_n_genes_by_counts', 'total_counts', 'log1p_total_counts', 'pct_counts_in_top_50_genes', 'pct_counts_in_top_100_genes', 'pct_counts_in_top_200_genes', 'pct_counts_in_top_500_genes', 'total_counts_MT', 'log1p_total_counts_MT', 'pct_counts_MT', 'total_counts_ERCC', 'log1p_total_counts_ERCC', 'pct_counts_ERCC', 'total_counts_endogenous', 'log1p_total_counts_endogenous', 'pct_counts_endogenous', 'cells_keep', 'dblf_cluster', 'dblf_cuts', 'dblf_score', 'dblf_weighted', 'dblf_difficulty', 'dblf_cxds_score', 'dblf_likely_origin', 'dblf_ambiguous_origin', 'dblf_genotype_predicted', '_scvi_batch', '_scvi_labels', 'leiden', 'celltype_clusters', 'leiden_R', 'cell_type', 'monocyte_response', 'GEC_response', 'NK1_response']
