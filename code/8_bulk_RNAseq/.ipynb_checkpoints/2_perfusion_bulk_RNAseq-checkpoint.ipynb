# %%
#bulk RNAseq perfusion
setwd("~/ben_lustre/current_projects/kidney_glomTI_response")
suppressPackageStartupMessages(source("https://raw.githubusercontent.com/bjstewart1/helpful_singlecell/main/functions.R"))
ad <- import("anndata")
sc <- import("scanpy")
clean_theme <- theme_bw() + theme(axis.text = element_text(color = "black"), axis.title = element_text(color = "black"))
library(ggplot2)
# Out:
# Warning message:
# “The `size` argument of `element_rect()` is deprecated as of ggplot2 3.4.0.
# ℹ Please use the `linewidth` argument instead.”

# %%
sequencing_inventory <- read.csv("~/ben_nfs/sample_donor_data/sequencing_inventory.csv")
bulk_donors <- sequencing_inventory[sequencing_inventory$experiment %in%  "bulk_RNA_seq", ]
bulk_donors= bulk_donors[bulk_donors$submission_channel %in% 'bulk_kidney_cortex', ]
channels = bulk_donors$sanger_ID

# %%
#read in counts
tab = read.table("./data/seq_data/bulk_RNAseq/results-study6642-tic1844/combined/study6642-tic1844-star-genecounts.txt",
                header = TRUE, row.names = 1)
counts = tab
counts = counts[rownames(counts) %in% grep("ENSG*", rownames(counts), value = TRUE), ]
counts = counts[, channels]
#remove ERCC and other elements that we don't want
saveRDS(counts, "./data/seq_data/bulk_RNAseq/bulk_perfusion_cortex_counts.RDS")

# %%
#annotate genes
library(biomaRt)
ensembl <- useEnsembl(biomart = "genes", dataset = "hsapiens_gene_ensembl")
gene_symbols = getBM(attributes = c('ensembl_gene_id', 'external_gene_name', 'gene_biotype'),
      filters = 'ensembl_gene_id',
      values = rownames(counts), 
      mart = ensembl)
gene_symbols = data.frame(gene_symbols, row.names = 1)
annotation = data.frame("feature" = rownames(counts), gene_symbols[rownames(counts), ])
colnames(annotation) = c("ID", "Symbol", "biotype")

# %%
stimulation = c("K281" = "IC", "K282" = "IC", "K283" = "control", 
               "K287" = "IC", "K288" = "control", "K289" = "IC", "K290" = "control")
donor_mapping = c("K281" = "donor1", "K282" = "donor2", "K283" = "donor2",
                  "K287" = "donor3", "K288" = "donor3", "K289" = "donor4", "K290" = "donor4")
metadata <- bulk_donors
metadata = do.call(rbind, lapply(strsplit( metadata$sequencing_sample_name, "-"), 
       function(x){data.frame("donor" = x[1], 'timepoint' = gsub("T", "", x[2]))}))
metadata$stimulation = stimulation[metadata$donor]
metadata$kidney_pair = donor_mapping[metadata$donor]

# %%
metadata
# Out:
#    donor timepoint stimulation kidney_pair
# 1  K288  4         control     donor3
# 2  K288  2         control     donor3
# 3  K287  4         IC          donor3
# 4  K287  0         IC          donor3
# 5  K287  2         IC          donor3
# 6  K288  0         control     donor3
# 7  K281  4         IC          donor1
# 8  K281  2         IC          donor1
# 9  K281  0         IC          donor1
# 10 K290  0         control     donor4
# 11 K289  0         IC          donor4
# 12 K289  2         IC          donor4
# 13 K290  2         control     donor4
# 14 K289  4         IC          donor4
# 15 K290  4         control     donor4
# 16 K282  0         IC          donor2
# 17 K283  2         control     donor2
# 18 K283  0         control     donor2
# 19 K283  4         control     donor2
# 20 K282  4         IC          donor2
# 21 K282  2         IC          donor2

# %%
annotation = annotation[rownames(counts), ]
colnames(counts) = NULL
rownames(counts) = NULL

# %%
#timepoint DE
library(DESeq2)
dds <- DESeqDataSetFromMatrix(countData = counts,
                              colData = metadata,
                              rowData = annotation,
                             design = ~stimulation)
#subset to protein coding genes
dds = dds[rowData(dds)$biotype %in% "protein_coding", ]
dds = dds[!rowData(dds)$Symbol %in% "", ] #get the symbols with names
keep <- rowSums(counts(dds)) > 10
dds <- dds[keep,]
dds <- DESeq(dds)
gene_expr <- vst(dds, blind=FALSE)
res <- results(dds)
res$Symbol <- rowData(dds)[rownames(res), "Symbol"]
res <- res[!is.na(res$padj), ]
res$significant <- ifelse(res$padj < 0.05 & abs(res$log2FoldChange) > 1, "significant", "nonsignificant"
# Out:
# Warning message in DESeqDataSet(se, design = design, ignoreRank):
# “some variables in design formula are characters, converting to factors”
# estimating size factors
#
# estimating dispersions
#
# gene-wise dispersion estimates
#
# mean-dispersion relationship
#
# final dispersion estimates
#
# fitting model and testing
#
# -- replacing outliers and refitting for 431 genes
# -- DESeq argument 'minReplicatesForReplace' = 7
# -- original counts are preserved in counts(dds)
#
# estimating dispersions
#
# fitting model and testing

# %%
library(DESeq2)
dds <- DESeqDataSetFromMatrix(countData = counts[, metadata$stimulation %in% 'control'],
                              colData = metadata[metadata$stimulation %in% 'control',],
                              rowData = annotation,
                             design = ~kidney_pair+timepoint)
#subset to protein coding genes
dds = dds[rowData(dds)$biotype %in% "protein_coding", ]
dds = dds[!rowData(dds)$Symbol %in% "", ] #get the symbols with names
keep <- rowSums(counts(dds)) > 10
dds <- dds[keep,]
dds <- DESeq(dds)
gene_expr <- vst(dds, blind=FALSE)
res <- results(dds)
res$Symbol <- rowData(dds)[rownames(res), "Symbol"]
res <- res[!is.na(res$padj), ]
res$significant <- ifelse(res$padj < 0.01 & abs(res$log2FoldChange) > 2, "significant", "nonsignificant")
# Out:
# Warning message in DESeqDataSet(se, design = design, ignoreRank):
# “some variables in design formula are characters, converting to factors”
# estimating size factors
#
# estimating dispersions
#
# gene-wise dispersion estimates
#
# mean-dispersion relationship
#
# final dispersion estimates
#
# fitting model and testing

# %%
res = res[order(res$stat, decreasing = TRUE), ]
head(data.frame(res), 30)
# Out:
#                 baseMean   log2FoldChange lfcSE     stat      pvalue
# ENSG00000128591 1494.46849 4.050151       0.3007096 13.468645 2.392145e-41
# ENSG00000175793  434.42983 5.337946       0.4096559 13.030318 8.226413e-39
# ENSG00000058085  782.57653 3.438273       0.2925491 11.752807 6.831124e-32
# ENSG00000162413 2033.11242 2.465111       0.2305072 10.694292 1.082436e-26
# ENSG00000101255  252.09038 4.287990       0.4041045 10.611092 2.646383e-26
# ENSG00000196878  931.63796 3.332082       0.3195466 10.427529 1.856530e-25
# ENSG00000163661  930.68239 6.741222       0.6599567 10.214642 1.705081e-24
# ENSG00000160712 1778.80954 2.077769       0.2363419  8.791369 1.477482e-18
# ENSG00000196182 1693.86704 1.970812       0.2272974  8.670631 4.297324e-18
# ENSG00000160789 5421.73235 2.008806       0.2429594  8.268074 1.361407e-16
# ENSG00000189410  221.43398 3.491865       0.4298125  8.124159 4.504741e-16
# ENSG00000108342  218.78900 7.612397       0.9405078  8.093922 5.777366e-16
# ENSG00000078269  366.18276 2.088830       0.2627069  7.951182 1.847408e-15
# ENSG00000103257  585.45666 3.129198       0.3963392  7.895252 2.897291e-15
# ENSG00000103855  549.84244 1.817344       0.2306031  7.880831 3.252118e-15
# ENSG00000104885 1923.71030 2.143629       0.2751227  7.791540 6.619760e-15
# ENSG00000137309 1058.55013 3.191238       0.4143292  7.702178 1.337661e-14
# ENSG00000073008 1443.54680 2.695993       0.3514750  7.670512 1.713110e-14
# ENSG00000116871 2004.07410 2.780324       0.3693464  7.527685 5.164776e-14
# ENSG00000135094   44.46979 3.026580       0.4026525  7.516605 5.621678e-14
# ENSG00000180730  131.63429 2.855865       0.3804107  7.507320 6.035012e-14
# ENSG00000139725  124.66070 2.585038       0.3478237  7.432035 1.069394e-13
# ENSG00000129911  353.96788 2.103552       0.2872275  7.323644 2.413259e-13
# ENSG00000176170  298.20260 4.121288       0.5653753  7.289473 3.111693e-13
# ENSG00000118898  728.07282 1.802074       0.2502946  7.199813 6.029498e-13
# ENSG00000115221 1246.36566 1.832717       0.2545806  7.198968 6.066984e-13
# ENSG00000167767  123.65560 2.642416       0.3716220  7.110496 1.156267e-12
# ENSG00000188112  207.29810 2.844937       0.4021869  7.073669 1.508898e-12
# ENSG00000186174 1108.83009 2.165639       0.3095011  6.997192 2.611425e-12
# ENSG00000132510 2348.59666 2.254495       0.3232014  6.975512 3.047592e-12
#                 padj         Symbol   significant
# ENSG00000128591 3.556641e-37 FLNC     significant
# ENSG00000175793 6.115515e-35 SFN      significant
# ENSG00000058085 3.385505e-28 LAMC2    significant
# ENSG00000162413 4.023416e-23 KLHL21   significant
# ENSG00000101255 7.869285e-23 TRIB3    significant
# ENSG00000196878 4.600482e-22 LAMB3    significant
# ENSG00000163661 3.621592e-21 PTX3     significant
# ENSG00000160712 2.745901e-15 IL6R     significant
# ENSG00000196182 7.099179e-15 STK40    nonsignificant
# ENSG00000160789 2.024140e-13 LMNA     significant
# ENSG00000189410 6.088772e-13 SH2D5    significant
# ENSG00000108342 7.158156e-13 CSF3     significant
# ENSG00000078269 2.112866e-12 SYNJ2    significant
# ENSG00000103257 3.076923e-12 SLC7A5   significant
# ENSG00000103855 3.223499e-12 CD276    nonsignificant
# ENSG00000104885 6.151412e-12 DOT1L    significant
# ENSG00000137309 1.104908e-11 HMGA1    significant
# ENSG00000073008 1.340554e-11 PVR      significant
# ENSG00000116871 3.839495e-11 MAP7D1   significant
# ENSG00000135094 3.980148e-11 SDS      significant
# ENSG00000180730 4.078571e-11 SHISA2   significant
# ENSG00000139725 6.912937e-11 RHOF     significant
# ENSG00000129911 1.435213e-10 KLF16    significant
# ENSG00000176170 1.779410e-10 SPHK1    significant
# ENSG00000118898 3.221569e-10 PPL      nonsignificant
# ENSG00000115221 3.221569e-10 ITGB6    nonsignificant
# ENSG00000167767 5.928063e-10 KRT80    significant
# ENSG00000188112 7.397841e-10 C6orf132 significant
# ENSG00000186174 1.213333e-09 BCL9L    significant
# ENSG00000132510 1.373079e-09 KDM6B    significant

# %%
ggplot(data.frame(res), aes(x = log2FoldChange, y = -log(pvalue), color = significant)) + ggrastr::geom_point_rast(pch=19) + 
           scale_color_manual(values = c("significant" = 'red', "nonsignificant" = 'grey90'))  + theme_minimal()
# Out:
# plot without title

# %%
gene_expr
# Out:
# class: DESeqTransform
# dim: 16118 9
# metadata(1): version
# assays(1): ''
# rownames(16118): ENSG00000000003 ENSG00000000005 ... ENSG00000284713
#   ENSG00000284730
# rowData names(37): ID Symbol ... maxCooks dispFit
# colnames(9): 1 2 ... 8 9
# colData names(5): donor timepoint stimulation kidney_pair sizeFactor

# %%
library(msigdbr)
t2g= msigdbr(species = 'Homo sapiens', category = "H")[, c('gs_name', 'gene_symbol')]
colnames(t2g) = c('TERM', 'GENE')

# %%
geneList = res$stat
names(geneList) = res$Symbol
geneList = geneList[order(geneList, decreasing = TRUE)]
enrichment_result <- GSEA(geneList, TERM2GENE = t2g, pvalueCutoff = 1)    
enr_df = enrichment_result@result
# Out:
# preparing geneSet collections...
#
# GSEA analysis...
#
# Warning message in fgseaMultilevel(pathways = pathways, stats = stats, minSize = minSize, :
# “For some pathways, in reality P-values are less than 1e-10. You can set the `eps` argument to zero for better estimation.”
# leading edge analysis...
#
# done...

# %%
enr_df
# Out:
#                                            ID
# HALLMARK_TNFA_SIGNALING_VIA_NFKB           HALLMARK_TNFA_SIGNALING_VIA_NFKB
# HALLMARK_INFLAMMATORY_RESPONSE             HALLMARK_INFLAMMATORY_RESPONSE
# HALLMARK_OXIDATIVE_PHOSPHORYLATION         HALLMARK_OXIDATIVE_PHOSPHORYLATION
# HALLMARK_EPITHELIAL_MESENCHYMAL_TRANSITION HALLMARK_EPITHELIAL_MESENCHYMAL_TRANSITION
# HALLMARK_FATTY_ACID_METABOLISM             HALLMARK_FATTY_ACID_METABOLISM
# HALLMARK_APICAL_JUNCTION                   HALLMARK_APICAL_JUNCTION
# HALLMARK_IL6_JAK_STAT3_SIGNALING           HALLMARK_IL6_JAK_STAT3_SIGNALING
# HALLMARK_MYC_TARGETS_V2                    HALLMARK_MYC_TARGETS_V2
# HALLMARK_HYPOXIA                           HALLMARK_HYPOXIA
# HALLMARK_BILE_ACID_METABOLISM              HALLMARK_BILE_ACID_METABOLISM
# HALLMARK_UNFOLDED_PROTEIN_RESPONSE         HALLMARK_UNFOLDED_PROTEIN_RESPONSE
# HALLMARK_P53_PATHWAY                       HALLMARK_P53_PATHWAY
# HALLMARK_ADIPOGENESIS                      HALLMARK_ADIPOGENESIS
# HALLMARK_MYOGENESIS                        HALLMARK_MYOGENESIS
# HALLMARK_PROTEIN_SECRETION                 HALLMARK_PROTEIN_SECRETION
# HALLMARK_ESTROGEN_RESPONSE_EARLY           HALLMARK_ESTROGEN_RESPONSE_EARLY
# HALLMARK_PEROXISOME                        HALLMARK_PEROXISOME
# HALLMARK_TGF_BETA_SIGNALING                HALLMARK_TGF_BETA_SIGNALING
# HALLMARK_INTERFERON_GAMMA_RESPONSE         HALLMARK_INTERFERON_GAMMA_RESPONSE
# HALLMARK_CHOLESTEROL_HOMEOSTASIS           HALLMARK_CHOLESTEROL_HOMEOSTASIS
# HALLMARK_IL2_STAT5_SIGNALING               HALLMARK_IL2_STAT5_SIGNALING
# HALLMARK_PI3K_AKT_MTOR_SIGNALING           HALLMARK_PI3K_AKT_MTOR_SIGNALING
# HALLMARK_ALLOGRAFT_REJECTION               HALLMARK_ALLOGRAFT_REJECTION
# HALLMARK_MTORC1_SIGNALING                  HALLMARK_MTORC1_SIGNALING
# HALLMARK_MITOTIC_SPINDLE                   HALLMARK_MITOTIC_SPINDLE
# HALLMARK_UV_RESPONSE_UP                    HALLMARK_UV_RESPONSE_UP
# HALLMARK_XENOBIOTIC_METABOLISM             HALLMARK_XENOBIOTIC_METABOLISM
# HALLMARK_SPERMATOGENESIS                   HALLMARK_SPERMATOGENESIS
# HALLMARK_PANCREAS_BETA_CELLS               HALLMARK_PANCREAS_BETA_CELLS
# HALLMARK_COMPLEMENT                        HALLMARK_COMPLEMENT
# HALLMARK_APOPTOSIS                         HALLMARK_APOPTOSIS
# HALLMARK_E2F_TARGETS                       HALLMARK_E2F_TARGETS
# HALLMARK_WNT_BETA_CATENIN_SIGNALING        HALLMARK_WNT_BETA_CATENIN_SIGNALING
# HALLMARK_ESTROGEN_RESPONSE_LATE            HALLMARK_ESTROGEN_RESPONSE_LATE
# HALLMARK_GLYCOLYSIS                        HALLMARK_GLYCOLYSIS
# HALLMARK_KRAS_SIGNALING_DN                 HALLMARK_KRAS_SIGNALING_DN
# HALLMARK_KRAS_SIGNALING_UP                 HALLMARK_KRAS_SIGNALING_UP
# HALLMARK_HEDGEHOG_SIGNALING                HALLMARK_HEDGEHOG_SIGNALING
# HALLMARK_REACTIVE_OXYGEN_SPECIES_PATHWAY   HALLMARK_REACTIVE_OXYGEN_SPECIES_PATHWAY
# HALLMARK_UV_RESPONSE_DN                    HALLMARK_UV_RESPONSE_DN
# HALLMARK_G2M_CHECKPOINT                    HALLMARK_G2M_CHECKPOINT
# HALLMARK_ANDROGEN_RESPONSE                 HALLMARK_ANDROGEN_RESPONSE
# HALLMARK_INTERFERON_ALPHA_RESPONSE         HALLMARK_INTERFERON_ALPHA_RESPONSE
# HALLMARK_HEME_METABOLISM                   HALLMARK_HEME_METABOLISM
# HALLMARK_COAGULATION                       HALLMARK_COAGULATION
# HALLMARK_APICAL_SURFACE                    HALLMARK_APICAL_SURFACE
# HALLMARK_ANGIOGENESIS                      HALLMARK_ANGIOGENESIS
# HALLMARK_DNA_REPAIR                        HALLMARK_DNA_REPAIR
# HALLMARK_NOTCH_SIGNALING                   HALLMARK_NOTCH_SIGNALING
# HALLMARK_MYC_TARGETS_V1                    HALLMARK_MYC_TARGETS_V1
#                                            Description
# HALLMARK_TNFA_SIGNALING_VIA_NFKB           HALLMARK_TNFA_SIGNALING_VIA_NFKB
# HALLMARK_INFLAMMATORY_RESPONSE             HALLMARK_INFLAMMATORY_RESPONSE
# HALLMARK_OXIDATIVE_PHOSPHORYLATION         HALLMARK_OXIDATIVE_PHOSPHORYLATION
# HALLMARK_EPITHELIAL_MESENCHYMAL_TRANSITION HALLMARK_EPITHELIAL_MESENCHYMAL_TRANSITION
# HALLMARK_FATTY_ACID_METABOLISM             HALLMARK_FATTY_ACID_METABOLISM
# HALLMARK_APICAL_JUNCTION                   HALLMARK_APICAL_JUNCTION
# HALLMARK_IL6_JAK_STAT3_SIGNALING           HALLMARK_IL6_JAK_STAT3_SIGNALING
# HALLMARK_MYC_TARGETS_V2                    HALLMARK_MYC_TARGETS_V2
# HALLMARK_HYPOXIA                           HALLMARK_HYPOXIA
# HALLMARK_BILE_ACID_METABOLISM              HALLMARK_BILE_ACID_METABOLISM
# HALLMARK_UNFOLDED_PROTEIN_RESPONSE         HALLMARK_UNFOLDED_PROTEIN_RESPONSE
# HALLMARK_P53_PATHWAY                       HALLMARK_P53_PATHWAY
# HALLMARK_ADIPOGENESIS                      HALLMARK_ADIPOGENESIS
# HALLMARK_MYOGENESIS                        HALLMARK_MYOGENESIS
# HALLMARK_PROTEIN_SECRETION                 HALLMARK_PROTEIN_SECRETION
# HALLMARK_ESTROGEN_RESPONSE_EARLY           HALLMARK_ESTROGEN_RESPONSE_EARLY
# HALLMARK_PEROXISOME                        HALLMARK_PEROXISOME
# HALLMARK_TGF_BETA_SIGNALING                HALLMARK_TGF_BETA_SIGNALING
# HALLMARK_INTERFERON_GAMMA_RESPONSE         HALLMARK_INTERFERON_GAMMA_RESPONSE
# HALLMARK_CHOLESTEROL_HOMEOSTASIS           HALLMARK_CHOLESTEROL_HOMEOSTASIS
# HALLMARK_IL2_STAT5_SIGNALING               HALLMARK_IL2_STAT5_SIGNALING
# HALLMARK_PI3K_AKT_MTOR_SIGNALING           HALLMARK_PI3K_AKT_MTOR_SIGNALING
# HALLMARK_ALLOGRAFT_REJECTION               HALLMARK_ALLOGRAFT_REJECTION
# HALLMARK_MTORC1_SIGNALING                  HALLMARK_MTORC1_SIGNALING
# HALLMARK_MITOTIC_SPINDLE                   HALLMARK_MITOTIC_SPINDLE
# HALLMARK_UV_RESPONSE_UP                    HALLMARK_UV_RESPONSE_UP
# HALLMARK_XENOBIOTIC_METABOLISM             HALLMARK_XENOBIOTIC_METABOLISM
# HALLMARK_SPERMATOGENESIS                   HALLMARK_SPERMATOGENESIS
# HALLMARK_PANCREAS_BETA_CELLS               HALLMARK_PANCREAS_BETA_CELLS
# HALLMARK_COMPLEMENT                        HALLMARK_COMPLEMENT
# HALLMARK_APOPTOSIS                         HALLMARK_APOPTOSIS
# HALLMARK_E2F_TARGETS                       HALLMARK_E2F_TARGETS
# HALLMARK_WNT_BETA_CATENIN_SIGNALING        HALLMARK_WNT_BETA_CATENIN_SIGNALING
# HALLMARK_ESTROGEN_RESPONSE_LATE            HALLMARK_ESTROGEN_RESPONSE_LATE
# HALLMARK_GLYCOLYSIS                        HALLMARK_GLYCOLYSIS
# HALLMARK_KRAS_SIGNALING_DN                 HALLMARK_KRAS_SIGNALING_DN
# HALLMARK_KRAS_SIGNALING_UP                 HALLMARK_KRAS_SIGNALING_UP
# HALLMARK_HEDGEHOG_SIGNALING                HALLMARK_HEDGEHOG_SIGNALING
# HALLMARK_REACTIVE_OXYGEN_SPECIES_PATHWAY   HALLMARK_REACTIVE_OXYGEN_SPECIES_PATHWAY
# HALLMARK_UV_RESPONSE_DN                    HALLMARK_UV_RESPONSE_DN
# HALLMARK_G2M_CHECKPOINT                    HALLMARK_G2M_CHECKPOINT
# HALLMARK_ANDROGEN_RESPONSE                 HALLMARK_ANDROGEN_RESPONSE
# HALLMARK_INTERFERON_ALPHA_RESPONSE         HALLMARK_INTERFERON_ALPHA_RESPONSE
# HALLMARK_HEME_METABOLISM                   HALLMARK_HEME_METABOLISM
# HALLMARK_COAGULATION                       HALLMARK_COAGULATION
# HALLMARK_APICAL_SURFACE                    HALLMARK_APICAL_SURFACE
# HALLMARK_ANGIOGENESIS                      HALLMARK_ANGIOGENESIS
# HALLMARK_DNA_REPAIR                        HALLMARK_DNA_REPAIR
# HALLMARK_NOTCH_SIGNALING                   HALLMARK_NOTCH_SIGNALING
# HALLMARK_MYC_TARGETS_V1                    HALLMARK_MYC_TARGETS_V1
#                                            setSize enrichmentScore NES
# HALLMARK_TNFA_SIGNALING_VIA_NFKB           193      0.5764492       2.9176580
# HALLMARK_INFLAMMATORY_RESPONSE             171      0.4786975       2.3760962
# HALLMARK_OXIDATIVE_PHOSPHORYLATION         198     -0.4796863      -2.3511680
# HALLMARK_EPITHELIAL_MESENCHYMAL_TRANSITION 191      0.4369810       2.2146998
# HALLMARK_FATTY_ACID_METABOLISM             148     -0.4246208      -1.9913169
# HALLMARK_APICAL_JUNCTION                   181      0.3872314       1.9493699
# HALLMARK_IL6_JAK_STAT3_SIGNALING            78      0.4933263       2.1456462
# HALLMARK_MYC_TARGETS_V2                     57      0.5357406       2.1931859
# HALLMARK_HYPOXIA                           188      0.3678345       1.8630662
# HALLMARK_BILE_ACID_METABOLISM              100     -0.4307162      -1.8944317
# HALLMARK_UNFOLDED_PROTEIN_RESPONSE         112      0.4141032       1.9189047
# HALLMARK_P53_PATHWAY                       190      0.3457383       1.7501725
# HALLMARK_ADIPOGENESIS                      192     -0.3547435      -1.7233112
# HALLMARK_MYOGENESIS                        166      0.3499853       1.7307084
# HALLMARK_PROTEIN_SECRETION                  96     -0.4221777      -1.8478738
# HALLMARK_ESTROGEN_RESPONSE_EARLY           185      0.3386681       1.7074871
# HALLMARK_PEROXISOME                         96     -0.3898945      -1.7065703
# HALLMARK_TGF_BETA_SIGNALING                 52      0.4413748       1.7639182
# HALLMARK_INTERFERON_GAMMA_RESPONSE         189      0.3023732       1.5305993
# HALLMARK_CHOLESTEROL_HOMEOSTASIS            73      0.3857353       1.6504616
# HALLMARK_IL2_STAT5_SIGNALING               186      0.2924511       1.4808281
# HALLMARK_PI3K_AKT_MTOR_SIGNALING           101      0.3436783       1.5872808
# HALLMARK_ALLOGRAFT_REJECTION               163      0.2940974       1.4481744
# HALLMARK_MTORC1_SIGNALING                  198      0.2825011       1.4378285
# HALLMARK_MITOTIC_SPINDLE                   190      0.2684353       1.3588546
# HALLMARK_UV_RESPONSE_UP                    144      0.2882512       1.3900002
# HALLMARK_XENOBIOTIC_METABOLISM             183     -0.2746283      -1.3276266
# HALLMARK_SPERMATOGENESIS                    79     -0.3297456      -1.3942126
# HALLMARK_PANCREAS_BETA_CELLS                21     -0.4834143      -1.4864392
# HALLMARK_COMPLEMENT                        184      0.2494696       1.2536122
# HALLMARK_APOPTOSIS                         151      0.2573814       1.2487743
# HALLMARK_E2F_TARGETS                       187     -0.2451186      -1.1847760
# HALLMARK_WNT_BETA_CATENIN_SIGNALING         39      0.3451615       1.2937068
# HALLMARK_ESTROGEN_RESPONSE_LATE            181      0.2297638       1.1566587
# HALLMARK_GLYCOLYSIS                        183      0.2286280       1.1483433
# HALLMARK_KRAS_SIGNALING_DN                 122     -0.2531372      -1.1535974
# HALLMARK_KRAS_SIGNALING_UP                 182      0.2225537       1.1189809
# HALLMARK_HEDGEHOG_SIGNALING                 34      0.3042178       1.1039560
# HALLMARK_REACTIVE_OXYGEN_SPECIES_PATHWA
# HALLMARK_COMPLEMENT                        4.850837e-02 1486
# HALLMARK_APOPTOSIS                         4.850837e-02 3126
# HALLMARK_E2F_TARGETS                       8.226394e-02 4087
# HALLMARK_WNT_BETA_CATENIN_SIGNALING        8.972202e-02 1380
# HALLMARK_ESTROGEN_RESPONSE_LATE            1.042522e-01 2297
# HALLMARK_GLYCOLYSIS                        1.048335e-01 2755
# HALLMARK_KRAS_SIGNALING_DN                 1.222754e-01 3162
# HALLMARK_KRAS_SIGNALING_UP                 1.267827e-01 2012
# HALLMARK_HEDGEHOG_SIGNALING                1.824109e-01 1870
# HALLMARK_REACTIVE_OXYGEN_SPECIES_PATHWAY   1.960766e-01  858
# HALLMARK_UV_RESPONSE_DN                    2.135663e-01 1268
# HALLMARK_G2M_CHECKPOINT                    2.135663e-01 3157
# HALLMARK_ANDROGEN_RESPONSE                 2.472960e-01 3516
# HALLMARK_INTERFERON_ALPHA_RESPONSE         2.719978e-01 2289
# HALLMARK_HEME_METABOLISM                   3.116124e-01 4019
# HALLMARK_COAGULATION                       3.116124e-01 4242
# HALLMARK_APICAL_SURFACE                    3.640341e-01 6083
# HALLMARK_ANGIOGENESIS                      3.817173e-01 1191
# HALLMARK_DNA_REPAIR                        4.315437e-01 3066
# HALLMARK_NOTCH_SIGNALING                   4.454486e-01 3081
# HALLMARK_MYC_TARGETS_V1                    4.631579e-01 2211
#                                            leading_edge
# HALLMARK_TNFA_SIGNALING_VIA_NFKB           tags=44%, list=13%, signal=39%
# HALLMARK_INFLAMMATORY_RESPONSE             tags=50%, list=22%, signal=39%
# HALLMARK_OXIDATIVE_PHOSPHORYLATION         tags=54%, list=29%, signal=39%
# HALLMARK_EPITHELIAL_MESENCHYMAL_TRANSITION tags=25%, list=9%, signal=23%
# HALLMARK_FATTY_ACID_METABOLISM             tags=47%, list=25%, signal=35%
# HALLMARK_APICAL_JUNCTION                   tags=23%, list=13%, signal=20%
# HALLMARK_IL6_JAK_STAT3_SIGNALING           tags=41%, list=18%, signal=34%
# HALLMARK_MYC_TARGETS_V2                    tags=33%, list=11%, signal=30%
# HALLMARK_HYPOXIA                           tags=21%, list=8%, signal=20%
# HALLMARK_BILE_ACID_METABOLISM              tags=56%, list=30%, signal=39%
# HALLMARK_UNFOLDED_PROTEIN_RESPONSE         tags=27%, list=17%, signal=22%
# HALLMARK_P53_PATHWAY                       tags=24%, list=14%, signal=21%
# HALLMARK_ADIPOGENESIS                      tags=46%, list=30%, signal=33%
# HALLMARK_MYOGENESIS                        tags=21%, list=11%, signal=19%
# HALLMARK_PROTEIN_SECRETION                 tags=57%, list=35%, signal=37%
# HALLMARK_ESTROGEN_RESPONSE_EARLY           tags=22%, list=11%, signal=19%
# HALLMARK_PEROXISOME                        tags=41%, list=18%, signal=34%
# HALLMARK_TGF_BETA_SIGNALING                tags=33%, list=16%, signal=27%
# HALLMARK_INTERFERON_GAMMA_RESPONSE         tags=26%, list=16%, signal=23%
# HALLMARK_CHOLESTEROL_HOMEOSTASIS           tags=26%, list=16%, signal=22%
# HALLMARK_IL2_STAT5_SIGNALING               tags=22%, list=15%, signal=19%
# HALLMARK_PI3K_AKT_MTOR_SIGNALING           tags=22%, list=14%, signal=19%
# HALLMARK_ALLOGRAFT_REJECTION               tags=34%, list=22%, signal=27%
# HALLMARK_MTORC1_SIGNALING                  tags=16%, list=11%, signal=14%
# HALLMARK_MITOTIC_SPINDLE                   tags=15%, list=11%, signal=14%
# HALLMARK_UV_RESPONSE_UP                    tags=28%, list=18%, signal=24%
# HALLMARK_XENOBIOTIC_METABOLISM             tags=36%, list=24%, signal=28%
# HALLMARK_SPERMATOGENESIS                   tags=51%, list=32%, signal=35%
# HALLMARK_PANCREAS_BETA_CELLS               tags=43%, list=20%, signal=34%
# HALLMARK_COMPLEMENT                        tags=16%, list=10%, signal=14%
# HALLMARK_APOPTOSIS                         tags=29%, list=21%, signal=23%
# HALLMARK_E2F_TARGETS                       tags=34%, list=27%, signal=25%
# HALLMARK_WNT_BETA_CATENIN_SIGNALING        tags=18%, list=9%, signal=16%
# HALLMARK_ESTROGEN_RESPONSE_LATE            tags=19%, list=15%, signal=17%
# HALLMARK_GLYCOLYSIS                        tags=24%, list=19%, signal=20%
# HALLMARK_KRAS_SIGNALING_DN                 tags=28%, list=21%, signal=22%
# HALLMARK_KRAS_SIGNALING_UP                 tags=19%, list=14%, signal=16%
# HALLMARK_HEDGEHOG_SIGNALING                tags=26%, list=13%, signal=23%
# HALLMARK_REACTIVE_OXYGEN_SPECIES_PATHWAY   tags=15%, list=6%, signal=14%
# HALLMARK_UV_RESPONSE_DN                    tags=12%, list=9%, signal=11%
# HALLMARK_G2M_CHECKPOINT                    tags=23%, list=21%, signal=18%
# HALLMARK_ANDROGEN_RESPONSE                 tags=30%, list=24%, signal=23%
# HALLMARK_INTERFERON_ALPHA_RESPONSE         tags=20%, list=15%, signal=17%
# HALLMARK_HEME_METABOLISM                   tags=33%, list=27%, signal=24%
# HALLMARK_COAGULATION                       tags=34%, list=29%, signal=25%
# HALLMARK_APICAL_SURFACE                    tags=53%, list=41%, signal=32%
# HALLMARK_ANGIOGENESIS                      tags=15%, list=8%, signal=14%
# HALLMARK_DNA_REPAIR                        tags=21%, list=21%, signal=17%
# HALLMARK_NOTCH_SIGNALING                   tags=29%, list=21%, signal=23%
# HALLMARK_MYC_TARGETS_V1                    tags=12%, list=15%, signal=10%
#                                            core_enrichment
# HALLMARK_TNFA_SIGNALING_VIA_NFKB           ...
# HALLMARK_INFLAMMATORY_RESPONSE             ...
# HALLMARK_OXIDATIVE_PHOSPHORYLATION         ...
# HALLMARK_EPITHELIAL_MESENCHYMAL_TRANSITION 
# HALLMARK_FATTY_ACID_METABOLISM             ...
# HALLMARK_APICAL_JUNCTION                   FLNC/LAMC2/LAMB3/CD276/RHOF/VASP/ZYX/TRAF1/ICAM1/NECTIN2/MYH9/ITGA3/NF2/GTF2F1/TAOK2/SRC/MVD/LAMA3/HRAS/CLDN6/CLDN4/CRB3/IKBKG/INSIG1/CX3CL1/SYMPK/TGFBI/YWHAH/CLDN5/STX4/MMP9/NECTIN1/ACTN2/CLDN15/DHX16/ITGA2/CLDN9/MPZL1/EGFR/NECTIN4/CLDN14/PFN1
# HALLMARK_DNA_REPAIR                        ZNF707/SNAPC4/VPS37B/GTF2F1/ADRM1/ERCC1/POLR2D/TAF13/BRF2/CANT1/STX3/ELL/TAF6/POLD4/GTF2H3/ERCC3/SAC3D1/FEN1/POLH/TAF1C/GTF2H1/NELFB/CLP1/PDE6G/NELFE/SUPT5H/ALYREF/AK1/POLR1C/MPG/SF3A3
# HALLMARK_NOTCH_SIGNALING                   DTX2/FZD1/PPARD/CCND1/DTX4/ARRB1/FZD5/DTX1/NOTCH3
# HALLMARK_MYC_TARGETS_V1                    RNPS1/TRIM28/SRM/RSL1D1/MYC/RRP9/EIF3B/SNRPD1/PSMD7/NOP16/RPS2/AIMP2/ODC1/PSMA6/PSMB2/POLE3/UBA2/EIF4E/LSM7/MRPL23/GSPT1/EIF2S2/IARS1

# %%
#now we do differential expression for each timepoint.
de_results = lapply(c(0, 2, 4), function(tp){
    message(paste0('timepoint ', tp))
    dds_use <- DESeqDataSetFromMatrix(countData = counts,
                              colData = metadata,
                              rowData = annotation,
                             design = ~kidney_pair + stimulation)
    #subset to protein coding genes
    dds_use = dds_use[rowData(dds_use)$biotype %in% "protein_coding", ]
    dds_use = dds_use[!rowData(dds_use)$Symbol %in% "", ] #get the symbols with names
    subdds = dds_use[, colData(dds_use)$timepoint == tp]
    keep <- rowSums(counts(subdds)) > 10
    subdds <- subdds[keep,]
    subdds <- DESeq(subdds)
    res <- results(subdds)
    res$Symbol <- rowData(subdds)[rownames(res), "Symbol"]
    res <- res[!is.na(res$padj), ]
    res$significant <- ifelse(res$pvalue < 0.05 & abs(res$log2FoldChange) > 1, "significant", "nonsignificant")
    return(res)
})
names(de_results) = c(0,2,4)
# Out:
# timepoint 0
#
# Warning message in DESeqDataSet(se, design = design, ignoreRank):
# “some variables in design formula are characters, converting to factors”
# estimating size factors
#
# estimating dispersions
#
# gene-wise dispersion estimates
#
# mean-dispersion relationship
#
# final dispersion estimates
#
# fitting model and testing
#
# timepoint 2
#
# Warning message in DESeqDataSet(se, design = design, ignoreRank):
# “some variables in design formula are characters, converting to factors”
# estimating size factors
#
# estimating dispersions
#
# gene-wise dispersion estimates
#
# mean-dispersion relationship
#
# final dispersion estimates
#
# fitting model and testing
#
# timepoint 4
#
# Warning message in DESeqDataSet(se, design = design, ignoreRank):
# “some variables in design formula are characters, converting to factors”
# estimating size factors
#
# estimating dispersions
#
# gene-wise dispersion estimates
#
# mean-dispersion relationship
#
# final dispersion estimates
#
# fitting model and testing

# %%
volcano_input = do.call(rbind, lapply(names(de_results), function(tp){
    de = data.frame(de_results[[tp]], 'timepoint' = tp)
    symbols = de[de$significant == 'significant' & de$log2FoldChange > 0, 'Symbol' ]
    de$label = de$Symbol
    de$label[!de$Symbol %in% symbols] = NA
return(de)
}))

# %%
options(repr.plot.width = 20, repr.plot.height = 7)
volcano_plots = ggplot(volcano_input, aes(x = log2FoldChange, y = -log(pvalue), label = label, color = significant)) + ggrastr::geom_point_rast(pch=19) + facet_wrap(~timepoint) + 
           scale_color_manual(values = c("significant" = 'red', "nonsignificant" = 'grey90')) + geom_label() + theme_minimal()

# %%
pdf('./figures/bulk_perfusion_sequencing_volcanos.pdf', width = 22, height = 7)
volcano_plots
dev.off()
volcano_plots
# Out:
# Warning message:
# “Removed 47293 rows containing missing values (`geom_label()`).”
# png
#   2
# Warning message:
# “Removed 47293 rows containing missing values (`geom_label()`).”
# plot without title

# %%
#what is the intersection between the GEC signature and the bulk response signature
gec_signature =read.csv("./data/da_results/perfusion/response_signatures/GEC_response_geneset.csv")$X
bulk_response = volcano_input[volcano_input$significant == 'significant' & volcano_input$timepoint == '4' &  volcano_input$stat > 0, 'Symbol']
intersect(gec_signature, bulk_response)
# Out:
# [1] "CXCL3" "SELE"  "IL6"   "CSF3"  "CXCL8" "CXCL2" "CXCL1"

# %%
#now get the response signatures and look for enrichment at each timepoint
library(clusterProfiler)
t2g = do.call(rbind, lapply(c("classical_monocyte", "NK1", "GEC"), function(ct){
    fp = file.path("./data/da_results/perfusion/response_signatures", paste0(ct, "_response_geneset.csv"))
    signature =read.csv(fp)$X
    df = data.frame("TERM" = ct, "GENE" = signature)
    return(df)
}))
enrichments = do.call(rbind, lapply(c('0', '2', '4'), function(tp){
de = volcano_input[volcano_input$timepoint == tp,]
geneList = de$stat
names(geneList) = de$Symbol
geneList = geneList[order(geneList, decreasing = TRUE)]
enrichment_result <- GSEA(geneList, TERM2GENE = t2g, pvalueCutoff = 1)    
enr_df = data.frame(enrichment_result@result, 'timepoint' = tp)
    return(enr_df)
}))
# Out:
# Registered S3 methods overwritten by 'treeio':
#   method              from
#   MRCA.phylo          tidytree
#   MRCA.treedata       tidytree
#   Nnode.treedata      tidytree
#   Ntip.treedata       tidytree
#   ancestor.phylo      tidytree
#   ancestor.treedata   tidytree
#   child.phylo         tidytree
#   child.treedata      tidytree
#   full_join.phylo     tidytree
#   full_join.treedata  tidytree
#   groupClade.phylo    tidytree
#   groupClade.treedata tidytree
#   groupOTU.phylo      tidytree
#   groupOTU.treedata   tidytree
#   is.rooted.treedata  tidytree
#   nodeid.phylo        tidytree
#   nodeid.treedata     tidytree
#   nodelab.phylo       tidytree
#   nodelab.treedata    tidytree
#   offspring.phylo     tidytree
#   offspring.treedata  tidytree
#   parent.phylo        tidytree
#   parent.treedata     tidytree
#   root.treedata       tidytree
#   rootnode.phylo      tidytree
#   sibling.phylo       tidytree
#
# clusterProfiler v4.6.2  For help: https://yulab-smu.top/biomedical-knowledge-mining-book/
#
# If you use clusterProfiler in published research, please cite:
# T Wu, E Hu, S Xu, M Chen, P Guo, Z Dai, T Feng, L Zhou, W Tang, L Zhan, X Fu, S Liu, X Bo, and G Yu. clusterProfiler 4.0: A universal enrichment tool for interpreting omics data. The Innovation. 2021, 2(3):100141
#
#
# Attaching package: ‘clusterProfiler’
#
#
# The following object is masked from ‘package:biomaRt’:
#
#     select
#
#
# The following object is masked from ‘package:igraph’:
#
#     simplify
#
#
# The following object is masked from ‘package:IRanges’:
#
#     slice
#
#
# The following object is masked from ‘package:S4Vectors’:
#
#     rename
#
#
# The following object is masked from ‘package:stats’:
#
#     filter
#
#
# preparing geneSet collections...
#
# GSEA analysis...
#
# Warning message in preparePathwaysAndStats(pathways, stats, minSize, maxSize, gseaParam, :
# “There are duplicate gene names, fgsea may produce unexpected results.”
# leading edge analysis...
#
# done...
#
# preparing geneSet collections...
#
# GSEA analysis...
#
# Warning message in preparePathwaysAndStats(pathways, stats, minSize, maxSize, gseaParam, :
# “There are ties in the preranked stats (0.01% of the list).
# The order of those tied genes will be arbitrary, which may produce unexpected results.”
# Warning message in preparePathwaysAndStats(pathways, stats, minSize, maxSize, gseaParam, :
# “There are duplicate gene names, fgsea may produce unexpected results.”
# leading edge analysis...
#
# done...
#
# preparing geneSet collections...
#
# GSEA analysis...
#
# Warning message in preparePathwaysAndStats(pathways, stats, minSize, maxSize, gseaParam, :
# “There are ties in the preranked stats (0.27% of the list).
# The order of those tied genes will be arbitrary, which may produce unexpected results.”
# Warning message in preparePathwaysAndStats(pathways, stats, minSize, maxSize, gseaParam, :
# “There are duplicate gene names, fgsea may produce unexpected results.”
# leading edge analysis...
#
# done...

# %%
options(repr.plot.width = 5, repr.plot.height = 5)
enrichments$p.adjust[enrichments$p.adjust >0.05] = NA
enrichment_gsea = ggplot(enrichments, aes(x = NES, y = ID, size = -log(p.adjust), fill = -log(p.adjust))) + geom_point(pch=21) + facet_wrap(~timepoint, ncol =1) + 
scale_fill_gradientn(colors = viridis::cividis(100))
pdf('./figures/perfusion_bulk_GSEA.pdf')
enrichment_gsea
dev.off()
# Out:
# Warning message:
# “Removed 3 rows containing missing values (`geom_point()`).”
# png
#   2

# %%
#now we work on the single cell perturbation data... 
#get the gene expression proportions within the target cell type
sc = import('scanpy')
adata = sc$read_h5ad('./data/annotated/scRNAseq_glom_TI_kidney.h5ad')

# %%
#prepare the bulk data
dds <- dds[!duplicated(rowData(dds)$Symbol), ]
bulk_data <- data.frame(assay(dds), row.names = rowData(dds)$Symbol)
idx <- intersect(rownames(bulk_data), adata$var_names$values)
adata = py_eval('r.adata[:, r.idx]' )
bulk_data <- bulk_data[idx, ]

# %%
library(SCDC) #this works quite well.
sc_eset <- getESET(t(adata$layers['raw_counts']), fdata = adata$var, pdata = adata$obs)
rownames(sc_eset) <- adata$var_names$values
bulk_eset <- ExpressionSet(as.matrix(bulk_data), fdata = adata$var, pdata = colData(dds))
props <- SCDC_prop( bulk_eset, sc_eset, ct.varname = "broad_cell_type", sample = "genotype", ct.sub = unique(sc_eset$broad_cell_type))

# %%
saveRDS(props, './data/bulk_RNAseq/perfusion/deconvolution_results.RDS')

# %%
#get our cell type proportions
celltype_proportions <- props$prop.est.mvw
df_plot = reshape::melt(celltype_proportions)

# %%
celltypes_test = c('podocyte','GPEC','PTEC','TAL_LOH','DTL_LOH','DCT','CNT','PC','IC','collecting_duct','AE','GEC','PCE','MC','Mfib','VSMC')
df_plot = df_plot[df_plot$X2 %in% celltypes_test, ]
df_plot$X2 = factor(df_plot$X2, levels =celltypes_test )

# %%
pdf("./figures/perfusion_bulk_deconv.pdf")
ggplot(df_plot, aes(x = X2, y = value, group = X1)) + 
  geom_line(alpha = 0.7, color = 'grey') + geom_point(pch = 21, size = 2, alpha = 0.7) +   theme_cowplot() + 
  theme(axis.text.x = element_text(angle = 45, hjust = 1, color = 'black'), legend.position = 'none') + 
  xlab("") + ylab("proportion of library")
dev.off()

# %%
library(CoGAPS)

# %%
#get the gene expression data
gene_expr = gene_expr[!duplicated(rowData(gene_expr)$Symbol), ]
gex_in = assay(gene_expr)
rownames(gex_in) = rowData(gene_expr)$Symbol
colnames(gex_in) = channels

# %%
#define some variable genes
gex_var = apply(gex_in, 1, var)
gex_mean = apply(gex_in, 1, mean)

# %%
ggplot(data.frame("mean" = gex_mean, 'var' = gex_var), aes(x=mean, y = var)) + geom_point(pch = 19, cex=0.01)
var_genes = gex_var >2
# Out:
# plot without title

# %%
# create new parameters object
params <- new("CogapsParams")
getParam(params, "nPatterns")
params <- setParam(params, "nPatterns", 6)
getParam(params, "nPatterns")
cogapsresult <- CoGAPS(gex_in[var_genes, ], params, outputFrequency = 10000)
# Out:
# [1] 7
# [1] 6
# This is CoGAPS version 3.21.5
# Running Standard CoGAPS on gex_in[var_genes, ] (1730 genes and 21 samples) with parameters:
#
# -- Standard Parameters --
# nPatterns            6
# nIterations          50000
# seed                 585
# sparseOptimization   FALSE
#
# -- Sparsity Parameters --
# alpha          0.01
# maxGibbsMass   100

# %%
pm <- patternMarkers(cogapsresult, threshold="cut")
# Out:
# Warning message in sweep(As, 2, pscale, FUN = "*"):
# “STATS is longer than the extent of 'dim(x)[MARGIN]'”

# %%
pm$PatternMarkers[[3]]
# Out:
# [181] "KBTBD4"    "SLC26A9"   "C9orf72"   "HEPH"      "ANG"       "JAZF1"
# [187] "PCDH15"    "SERPINA3"  "OR2T10"    "TRAF3IP3"  "CNTN1"     "FMO3"
# [193] "H1-3"      "CTSK"      "ZNF229"    "NUSAP1"    "CD53"

# %%
pheatmap(cor(cogapsresult@sampleFactors))
# Out:
# plot without title

# %%
pheatmap(cogapsresult@sampleFactors)
# Out:
# plot without title

# %%
factor_df = cbind(cogapsresult@sampleFactors, metadata)

# %%
ggplot(factor_df, aes(x = timepoint, group = donor, color = stimulation, y = Pattern_4)) +  geom_line() + geom_point()
# Out:
# plot without title

# %%
library(org.Hs.eg.db)

# %%
#do enrichGO on the pattern markers
go_results = lapply(pm$PatternMarkers, function(p){
    ego <- clusterProfiler::enrichGO(gene= p, universe= names(var_genes[var_genes]),
                OrgDb = org.Hs.eg.db, ont = "BP", pAdjustMethod = "BH", pvalueCutoff  = 0.01, qvalueCutoff  = 0.05, keyType = 'SYMBOL', readable= TRUE)
    return(ego@result)

})

# %%
hallmarks <- getPatternHallmarks(cogapsresult)
# Out:
# Warning message in sweep(As, 2, pscale, FUN = "*"):
# “STATS is longer than the extent of 'dim(x)[MARGIN]'”

# %%
head(hallmarks[[5]]$overlapGenes)
# Out:
# [[1]]
# [1] "AHR"      "FLT3LG"   "TNFRSF18"
#
# [[2]]
# [1] "POLR2D" "TAF13"
#
# [[3]]
# [1] "MARCKS"  "TNFAIP2"
#
# [[4]]
# [1] "SRXN1"
#
# [[5]]
# [1] "PRKAR2A"
#
# [[6]]
# [1] "PRKAR2A"

# %%
features = cogapsresult@featureLoadings
feature_loadings = lapply(colnames(features), function(c){features[order(features[, c], decreasing = T), c]})
feature_loadings[[4]]
# Out:
#         METTL7A           MED18            PLEC           ICAM1            G0S2
#    1.382852e+01    1.377775e+01    1.365247e+01    1.357935e+01    1.357412e+01
#           MAGT1          COL7A1          RPL7L1          TRIM56         CEBPZOS
#    1.325004e+01    1.283188e+01    1.278932e+01    1.238833e+01    1.238824e+01
#          TLNRD1         TNFSF15           PGAM5         PRKAR2A          PCSK1N
#    1.218536e+01    1.217820e+01    1.216276e+01    1.198327e+01    1.198071e+01
#          AKR1C2            MDM4            CLPX            CRCP            NOCT
#    1.190608e+01    1.186468e+01    1.180065e+01    1.179567e+01    1.175963e+01
#             AHR           RAB2B         PHACTR4        C11orf96         TNFAIP2
#    1.174695e+01    1.167494e+01    1.164948e+01    1.159094e+01    1.157752e+01
#            LIPG           SGPP2          MAP7D1          ZNF316          AKR1C1
#    1.155284e+01    1.145263e+01    1.144991e+01    1.141926e+01    1.138455e+01
#       TNFRSF12A          MRPL30            IL11          ZNF587          NEURL3
#    1.136430e+01    1.129615e+01    1.127054e+01    1.126659e+01    1.123518e+01
#          PLCXD1           LIMD1          POLR2D         DENND6A          DCAF16
#    1.123138e+01    1.122876e+01    1.121666e+01    1.117935e+01    1.114217e+01
#            RRAD             LIF          ZNF486           TAF13            MRI1
#    1.112406e+01    1.111763e+01    1.110045e+01    1.104257e+01    1.102486e+01
colnames(gex) = channels
gex = data.frame(gex)

cemi = cemitool(gex, force_beta = TRUE)
modules_out = module_genes(cemi)
modules = lapply(unique(modules_out[, 2]), function(x){modules_out[modules_out[,2] %in% x,1]})
names(modules) = unique(modules_out[, 2])

# %%
eigens <- mod_summary(cemi)
eigens = t(data.frame(eigens[!eigens[, 1] %in% "Not.Correlated", 2:ncol(eigens)], row.names = eigens[!eigens[, 1] %in% "Not.Correlated", 1]))

# %%
dfAnnotation = data.frame("Sample" = colnames(counts),
                          "Condition" = metadata$stimulation,
                          "Time" = as.numeric(metadata$timepoint),
                         "Kidney_pair" = metadata$kidney_pair,
                         "Kidney" = metadata$donor)
rownames(dfAnnotation) = dfAnnotation$Sample
h = t(eigens)
rownames(h) = 1:ncomp
pheatmap(h[, order(paste0(dfAnnotation$Time, dfAnnotation$Condition))], annotation_col = dfAnnotation[, c('Time', 'Condition')], cluster_cols = FALSE, 
        cluster_rows = FALSE, color = viridis::magma(10))

# %%
#plot h against time
df = data.frame(dfAnnotation, eigens)

# %%
head(df)

# %%
ggplot(df, aes(x = Time, y = M1, fill = Condition, group = Kidney))  + geom_line() + geom_point(pch = 21, size = 5, alpha = 0.4) + 
facet_wrap(~Kidney_pair) + scale_fill_manual(values = c("control" = 'grey50', "IC" = 'red'))+ theme_bw()

# %%
modules$M1

# %%
#now do NMF

# %%
#get variable genes
variable = apply(c_out, 1, var)
variable = variable[order(variable, decreasing = TRUE)]
variable = variable[1:1000]

# %%
library(NMF)
nmf_in = c_out[names(variable), ]
ncomp = 3
set.seed(100)
res <- nmf(nmf_in,ncomp)

# %%
res

# %%
w <- basis(res)
dim(w)
# get matrix H
h <- coef(res)
dim(h)

# %%
dfAnnotation = data.frame("Sample" = colnames(counts),
                          "Condition" = metadata$stimulation,
                          "Time" = as.numeric(metadata$timepoint),
                         "Kidney_pair" = metadata$kidney_pair,
                         "Kidney" = metadata$donor)
rownames(dfAnnotation) = dfAnnotation$Sample
rownames(h) = 1:ncomp
pheatmap(h[, order(paste0(dfAnnotation$Time, dfAnnotation$Condition))], annotation_col = dfAnnotation[, c('Time', 'Condition')], cluster_cols = FALSE, 
        cluster_rows = FALSE, color = viridis::magma(10))

# %%
#plot h against time
df = data.frame(dfAnnotation, t(h))

# %%
colnames(w) = 1:ncomp
loadings = lapply(colnames(w), function(x){
w[order(w[, x], decreasing = T), x]    
})
names(loadings) = colnames(w)
head(loadings[['2']], 50)

# %%
ggplot(df, aes(x = Time, y = X2, fill = Condition, group = Kidney))  + geom_line() + geom_point(pch = 21, size = 5, alpha = 0.4) + 
facet_wrap(~Kidney_pair) + scale_fill_manual(values = c("control" = 'grey50', "IC" = 'red'))+ theme_bw()

# %%
df$expr = assay(vsd)[which(rowData(vsd)$Symbol == 'P2RY14'), ]
ggplot(df, aes(x = Time, y = expr, fill = Condition, group = Kidney))  + geom_line() + geom_point(pch = 21, size = 5, alpha = 0.4) + 
facet_wrap(~Kidney_pair) + scale_fill_manual(values = c("control" = 'grey50', "IC" = 'red'))+ theme_bw() + ggtitle("gene expression")
