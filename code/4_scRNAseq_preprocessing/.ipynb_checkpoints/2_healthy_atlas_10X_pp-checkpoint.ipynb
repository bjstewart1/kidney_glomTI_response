# %%
project_dir = "~/ben_lustre/current_projects/kidney_glomTI_response"
setwd(project_dir)
suppressPackageStartupMessages(source("https://raw.githubusercontent.com/bjstewart1/helpful_singlecell/main/functions.R"))
ad <- import("anndata")
sc <- import("scanpy")
scv <- import("scvelo")
sp = import("scipy")
clean_theme <- theme_bw() + theme(axis.text = element_text(color = "black"), axis.title = element_text(color = "black"))
# Out:
# Warning message:
# “The `size` argument of `element_rect()` is deprecated as of ggplot2 3.4.0.
# ℹ Please use the `linewidth` argument instead.”

# %%
py_config()
# Out:
# python:         /home/jovyan/my-conda-envs/myenv/bin/python
# libpython:      /home/jovyan/my-conda-envs/myenv/lib/libpython3.8.so
# pythonhome:     /home/jovyan/my-conda-envs/myenv:/home/jovyan/my-conda-envs/myenv
# version:        3.8.8 | packaged by conda-forge | (default, Feb 20 2021, 16:22:27)  [GCC 9.3.0]
# numpy:          /home/jovyan/my-conda-envs/myenv/lib/python3.8/site-packages/numpy
# numpy_version:  1.20.3
#
# NOTE: Python version was forced by RETICULATE_PYTHON

# %%
tenx_dir <- "./data/seq_data/10X_3p"
sequencing_inventory <- read.csv("/nfs/team297/bs16/sample_donor_data/sequencing_inventory.csv", check.names = FALSE)
sequencing_inventory <- sequencing_inventory[sequencing_inventory$experiment %in% c("10X_3'_V3") & #just 3p
                                           sequencing_inventory$cellranger_SOC %in% 'TRUE' & sequencing_inventory$poor_QC %in% "FALSE",]
#exclude fetal - these are one per channel and we will analyse these elsewhere
sequencing_inventory <- sequencing_inventory[!sequencing_inventory$tissue %in% grep("fetal", sequencing_inventory$tissue, value = TRUE), ]
#remove perfusion samples
perfusion_batches = c("Batch_9", "Batch_12", "Batch_14")
sequencing_inventory = sequencing_inventory[!sequencing_inventory$tissue_dissociation_processing_batch %in% perfusion_batches, ]
#fix the irods spaces
sequencing_inventory$irods_ID <- gsub(" ", "", sequencing_inventory$irods_ID)

#make a set of channels and files
fn_in <- data.frame("channel" = sequencing_inventory$sanger_ID, "filename" = sequencing_inventory$irods_ID)

#now get the assignments
cell_assignments <- readRDS(file.path(project_dir,  "data/genotypes/cell_assignments_cells.RDS"))

# %%
adata = sc$read_h5ad("data/raw/10X_3p/healthy_raw_pre_QC.h5ad")

# %%
#add in depth information ####
depth_data <- read.csv("~/nfs/team297/bs16/sample_donor_data/scRNAseq_depths.csv")
depth_data <- reshape2::melt(depth_data)
adata$obs$depth <- as.character(adata$obs$anatomy)
adata$obs$depth[adata$obs$channel %in% unique(depth_data$Channel)] <- "depth_doublet"
for(i in seq_along(rownames(depth_data))){
  dpths <- depth_data[i, ]
  message(dpths$Channel)
  adata$obs$depth[adata$obs$genotype %in% dpths$variable & adata$obs$channel %in% dpths$Channel] <- dpths$value
}
# Out:
# Using Channel as id variables
#
# Well_KID10715494
#
# Well_KID10715495
#
# Well_KID10715496
#
# Well_KID10715497
#
# Well_KID10715498
#
# Well_KID10715494
#
# Well_KID10715495
#
# Well_KID10715496
#
# Well_KID10715497
#
# Well_KID10715498
#
# Well_KID10715494
#
# Well_KID10715495
#
# Well_KID10715496
#
# Well_KID10715497
#
# Well_KID10715498
#
# Well_KID10715494
#
# Well_KID10715495
#
# Well_KID10715496
#
# Well_KID10715497
#
# Well_KID10715498

# %%
#barplot of cells by channel
ggplot(data.frame(table(adata$obs$tissue)), aes(x = Var1, y = Freq)) + geom_col() + clean_theme + theme(axis.text.x = element_text(angle = 45, hjust = 1))
ggplot(data.frame(table(adata$obs$depth)), aes(x = Var1, y = Freq)) + geom_col() + clean_theme + theme(axis.text.x = element_text(angle = 45, hjust = 1))
# Out:
# plot without title
# plot without title

# %%
adata = adata$copy()

# %%
#now do some QC ####
adata$var$MT = 1:nrow(adata$var) %in% grep("^MT-", adata$var$Symbol)
sc$pp$calculate_qc_metrics(adata, qc_vars= list("MT"), inplace = TRUE, layer = 'raw_counts')

# %%
#QC cuts #####
n_genes_cut = log1p(250)
total_counts_cut= log1p(250)
pct_counts_in_top_50_genes_cut <- 70
pct_mito_cut_cells = 50


#plot study against number of genes
n_genes_histogram <- ggplot(adata$obs, aes(x = log1p_n_genes_by_counts)) + geom_histogram(bins = 100, fill = "grey30") + 
  geom_vline(xintercept = n_genes_cut, color = "red") + clean_theme

#density plot of genes by MT counts
qcpl1<- density_plot_raster(x = adata$obs$log1p_n_genes_by_counts, y= adata$obs$log1p_total_counts_MT) + 
  clean_theme + xlab("log1p_n_genes_by_counts") + 
  ylab("log1p_total_counts_MT") + geom_vline(xintercept = n_genes_cut, color = "red") + ggtitle("cells log total genes by log total MT counts")

#density plot of genes by pct counts in top 50 genes
qcpl2 <- density_plot_raster(x = adata$obs$log1p_n_genes_by_counts, y= adata$obs$pct_counts_in_top_50_genes) + 
  clean_theme + xlab("log1p_n_genes_by_counts") + 
  ylab("pct_counts_in_top_50_genes") + 
  geom_vline(xintercept = n_genes_cut, color = "red") + geom_hline(yintercept = pct_counts_in_top_50_genes_cut, color = "red") + 
  ylim(c(0, 100)) + ggtitle("cells log total genes by % counts top 50")


#density plot of genes by total counts
qcpl3 <- density_plot_raster(x = adata$obs$log1p_n_genes_by_counts, y= adata$obs$log1p_total_counts) + 
  clean_theme + ylab("log1p_total_counts") + 
  xlab("log1p_n_genes_by_counts") + 
  geom_vline(xintercept = n_genes_cut, color = "red") + 
  geom_hline(yintercept = total_counts_cut, color = "red") + ggtitle("cells log total counts by log total genes")
# Out:
# Loading required package: ggrastr
#
# Loading required package: MASS

# %%
options(repr.plot.width = 12, repr.plot.height = 4)
sc_qcpl = list(qcpl1, qcpl2, qcpl3)

# %%
#plot these out
options(repr.plot.width = 12, repr.plot.height = 4)
sc_qcpl = list(qcpl1, qcpl2, qcpl3)
saveRDS(sc_qcpl, "figures/4_2_qc_plots.RDS")
plot_grid(plotlist= sc_qcpl, nrow = 1, ncol = 3)
# Out:
# plot without title

# %%
#now make some cuts ####
bad_barcodes <- list(adata$obs_names$values[adata$obs$log1p_n_genes_by_counts < n_genes_cut], 
                     adata$obs_names$values[adata$obs$log1p_total_counts < total_counts_cut], 
                     adata$obs_names$values[adata$obs$pct_counts_in_top_50_genes > pct_counts_in_top_50_genes_cut])
bad_barcodes <- Reduce(union, bad_barcodes)

adata$obs$qc_cuts <- !adata$obs_names$values %in% bad_barcodes

#look at cell status
table(adata$obs$qc_cuts)

table(adata$obs$status)

#make the cuts
adata <- adata[adata$obs$qc_cuts]

#we will do % mitochondrial cuts on a cluster specific level later.
# Out:
#  FALSE   TRUE
#  94979 310831
#    doublet    singlet unassigned
#      15723     331257      58830

# %%
#remove unassigned cells ####
table(adata$obs$status) #small number of unassigned events
adata <- adata[!adata$obs$status %in% "unassigned"]
# Out:
#    doublet    singlet unassigned
#      12203     295150       3478

# %%
#add a core exclude set of genes ####
source('code/4_scRNAseq_preprocessing/nuissance_genes_grep.R')
adata$var$core_exclude <- core_exclude_grep(adata$var$Symbol)

# %%
#doublets
#run doublet processing
library(scDblFinder)
doublet_df = lapply(unique(adata$obs$channel), function(x){
message(x)
#subset the adata object
message("subsetting")
adata_sub = adata[adata$obs$channel %in% x]
#preprocess vanilla
message("preprocessing and clustering")
sc$pp$normalize_per_cell(adata_sub)
sc$pp$log1p(adata_sub)
#sc$pp$filter_genes(adata_sub, min_cells = ceiling(0.02*adata_sub$n_obs))
sc$pp$highly_variable_genes(adata_sub, flavor='seurat_v3', subset = FALSE, n_top_genes = as.integer(2000), layer = 'denoised_counts')
sc$pp$pca(adata_sub)
sc$pp$neighbors(adata_sub)
#cluster 
sc$tl$leiden(adata_sub, resolution = 1)
#make sce
#get count matrix
cmat = as(as.matrix(t(adata_sub$X)), "dgCMatrix") #unfortunately we have to do it this way..
#then make an SCE
sce = SingleCellExperiment::SingleCellExperiment(assays = list('counts' = cmat))
colnames(sce) = adata_sub$obs_names$values
#make some useful obs data
sce$known_doublets = adata_sub$obs$status %in% "doublet"
sce$clusters = adata_sub$obs$leiden
message("doublet analysis")
set.seed(100)
if(unique(adata_sub$obs$n_genotypes) > 1){
        message("more than one genotype in channel")
        set.seed(100)
sce <- scDblFinder(sce, 
                   knownDoublets = 'known_doublets',  #we use the known doublets we have
                   knownUse = 'discard',
                  clusters = 'clusters')
#get the fractions of each cluster that are from each genotype
samples = as.vector(table(factor(adata_sub$obs$genotype[adata_sub$obs$status %in% 'singlet'])))
reducedDim(sce, "PCA") = adata_sub$obsm$get("X_pca")
out <- recoverDoublets(sce, doublets=sce$known_doublets, k=15, samples= samples, use.dimred = 'PCA')
df = data.frame("dblf_cluster" = paste0(x, "_", colData(sce)$scDblFinder.cluster),
                "dblf_cuts" = colData(sce)$scDblFinder.class,
                "dblf_score" = colData(sce)$scDblFinder.score,
                "dblf_weighted" = colData(sce)$scDblFinder.weighted,
                "dblf_difficulty" = colData(sce)$scDblFinder.difficulty,
                "dblf_cxds_score" = colData(sce)$scDblFinder.cxds_score,
                "dblf_likely_origin" = colData(sce)$scDblFinder.mostLikelyOrigin,
                "dblf_ambiguous_origin" = colData(sce)$scDblFinder.originAmbiguous,
                "dblf_genotype_predicted" = ifelse(out$predicted, "doublet", "singlet"))}else{
    message("only one genotype in channel")
    #if not we don't have any known doublets
        set.seed(100)
    sce <- scDblFinder(sce, 
                  clusters = 'clusters')
df = data.frame("dblf_cluster" = paste0(x, "_", colData(sce)$scDblFinder.cluster),
                "dblf_cuts" = colData(sce)$scDblFinder.class,
                "dblf_score" = colData(sce)$scDblFinder.score,
                "dblf_weighted" = colData(sce)$scDblFinder.weighted,
                "dblf_difficulty" = colData(sce)$scDblFinder.difficulty,
                "dblf_cxds_score" = colData(sce)$scDblFinder.cxds_score,
                "dblf_likely_origin" = colData(sce)$scDblFinder.mostLikelyOrigin,
                "dblf_ambiguous_origin" = colData(sce)$scDblFinder.originAmbiguous,
                "dblf_genotype_predicted" = "singlet")
    }

return(df)
})
# Out:
# CG_SB_NB8768284
#
# subsetting
#
# preprocessing and clustering
#
# doublet analysis
#
# only one genotype in channel
#
# 16 clusters
#
# Creating ~5000 artificial doublets...
#
# Dimensional reduction
#
# Evaluating kNN...
#
# Training model...
#
# iter=0, 99 cells excluded from training.
#
# iter=1, 38 cells excluded from training.
#
# Threshold found:0.09
#
# 30 (1.2%) doublets called
#
# WSSS_A_KID9369817
#
# subsetting
#
# preprocessing and clustering
#
# Warning message in asMethod(object):
# “sparse->dense coercion: allocating vector of size 1.9 GiB”
# doublet analysis
#
# more than one genotype in channel
#
# 13 clusters
#
# Creating ~5000 artificial doublets...
#
# Dimensional reduction
#
# Evaluating kNN...
#
# Training model...
#
# iter=0, 909 cells excluded from training.
#
# iter=1, 663 cells excluded from training.
#
# Threshold found:0.005
#
# 287 (3.6%) doublets called
#
# WSSS_A_KID9369818
#
# subsetting
#
# preprocessing and clustering
#
# Warning message in asMethod(object):
# “sparse->dense coercion: allocating vector of size 2.1 GiB”
# doublet analysis
#
# more than one genotype in channel
#
# 16 clusters
#
# Creating ~5103 artificial doublets...
#
# Dimensional reduction
#
# Evaluating kNN...
#
# Training model...
#
# iter=0, 817 cells excluded from training.
#
# iter=1, 639 cells excluded from training.
#
# Threshold found:0.056
#
# 381 (4.3%) doublets called
#
# WSSS_A_KID9369819
#
# subsetting
#
# preprocessing and clustering
#
# Warning message in asMethod(object):
# “sparse->dense coercion: allocating vector of size 2.4 GiB”
# doublet analysis
#
# more than one genotype in channel
#
# 16 clusters
#
# Creating ~5660 artificial doublets...
#
# Dimensional reduction
#
# Evaluating kNN...
#
# Training model...
#
# iter=0, 862 cells excluded from training.
#
# iter=1, 709 cells excluded from training.
#
# Threshold found:0.008
#
# 475 (4.8%) doublets called
#
# WSSS_A_KID9369820
#
# subsetting
#
# preprocessing and clustering
#
# Warning message in asMethod(object):
# “sparse->dense coercion: allocating vector of size 2.0 GiB”
# doublet analysis
#
# more than one genotype in channel
#
# 17 clusters
#
# Creating ~5000 artificial doublets...
#
# Dimensional reduction
#
# Evaluating kNN...
#
# Training model...
#
# iter=0, 685 cells excluded from training.
#
# iter=1, 528 cells excluded from training.
#
# Threshold found:0.006
#
# 335 (4%) doublets called
#
# WSSS_A_KID9369821
#
# subsetting
#
# preprocessing and clustering
#
# Warning message in asMethod(object):
# “sparse->dense coercion: allocating vector of size 3.3 GiB”
# doublet analysis
#
# more than one genotype in channel
#
# 24 clusters
#
# Creating ~7817 artificial doublets...
#
# Dimensional reduction
#
# Evaluating kNN...
#
# Training model...
#
# iter=0, 1721 cells excluded from training.
#
# iter=1, 1535 cells excluded from training.
#
# Threshold found:0.029
#
# 924 (6.6%) doublets called
#
# WSSS_A_KID9383375
#
# subsetting
#
# preprocessing and clustering
#
# Warning message in asMethod(object):
# “sparse->dense coercion: allocating vector of size 2.1 GiB”
# doublet analysis
#
# more than one genotype in channel
#
# 18 clusters
#
# Creating ~5240 artificial doublets...
#
# Dimensional reduction
#
# Evaluating kNN...
#
# Training model...
#
# iter=0, 616 cells excluded from training.
#
# iter=1, 571 cells excluded from training.
#
# Threshold found:0.009
#
# 396 (4.4%) doublets called
#
# WSSS_A_KID9383376
#
# subsetting
#
# preprocessing and clustering
#
# Warning message in asMethod(object):
# “sparse->dense coercion: allocating vector of size 2.1 GiB”
# doublet analysis
#
# more than one genotype in channel
#
# 18 clusters
#
# Creating ~5013 artificial doublets...
#
# Dimensional reduction
#
# Evaluating kNN...
#
# Training model...
#
# iter=0, 618 cells excluded from training.
#
# iter=1, 494 cells excluded from training.
#
# Threshold found:0.007
#
# 377 (4.4%) doublets called
#
# WSSS_A_KID9383377
#
# subsetting
#
# preprocessing and clustering
#
# Warning message in asMethod(object):
# “sparse->dense coercion: allocating vector of size 1.8 GiB”
# doublet analysis
#
# more than one genotype in channel
#
# 19 clusters
#
# Creating ~5000 artificial doublets...
#
# Dimensional reduction
#
# Evaluating kNN...
#
# Training model...
#
# iter=0, 548 cells excluded from training.
#
# iter=1, 430 cells excluded from training.
#
# Threshold found:0.146
#
# 286 (3.7%) doublets called
#
# WSSS_A_KID9383567
#
# subsetting
#
# preprocessing and clustering
#
# Warning message in asMethod(object):
# “sparse->dense coercion: allocating vector of size 1.6 GiB”
# doublet analysis
#
# more than one genotype in channel
#
# 20 clusters
#
# Creating ~5000 artificial doublets...
#
# Dimensional reduction
#
# Evaluating kNN...
#
# Training model...
#
# iter=0, 565 cells excluded from training.
#
# iter=1, 446 cells excluded from training.
#
# Threshold found:0.171
#
# 214 (3.3%) doublets called
#
# WSSS_A_KID9383568
#
# subsetting
#
# preprocessing and clustering
#
# Warning message in asMethod(object):
# “sparse->dense coercion: allocating vector of size 1.5 GiB”
# doublet analysis
#
# more than one genotype in channel
#
# 22 clusters
#
# Creating ~5000 artificial doublets...
#
# Dimensional reduction
#
# Evaluating kNN...
#
# Training model...
#
# iter=0, 532 cells excluded from training.
#
# iter=1, 418 cells excluded from training.
#
# Threshold found:0.211
#
# 210 (3.3%) doublets called
#
# WSSS_A_KID9383569
#
# subsetting
#
# preprocessing and clustering
#
# doublet analysis
#
# more than one genotype in channel
#
# 16 clusters
#
# Creating ~5000 artificial doublets...
#
# Dimensional reduction
#
# Evaluating kNN...
#
# Training model...
#
# iter=0, 180 cells excluded from training.
#
# iter=1, 107 cells excluded from training.
#
# Threshold found:0.037
#
# 61 (1.8%) doublets called
#
# WSSS_A_KID9383572
#
# subsetting
#
# preprocessing and clustering
#
# Warning message in asMethod(object):
# “sparse->dense coercion: allocating vector of size 2.4 GiB”
# doublet analysis
#
# only one genotype in channel
#
# 16 clusters
#
# Creating ~6007 artificial doublets...
#
# Dimensional reduction
#
# Evaluating kNN...
#
# Training model...
#
# iter=0, 867 cells excluded from training.
#
# iter=1, 325 cells excluded from training.
#
# Threshold found:0.088
#
# 196 (2%) doublets called
#
# WSSS_A_KID9383573
#
# subsetting
#
# preprocessing and clustering
#
# Warning message in asMethod(object):
# “sparse->dense coercion: allocating vector of size 2.1 GiB”
# doublet analysis
#
# more than one genotype in channel
#
# 16 clusters
#
# Creating ~5000 artificial doublets...
#
# Dimensional reduction
#
# Evaluating kNN...
#
# Training model...
#
# iter=0, 799 cells excluded from training.
#
# iter=1, 584 cells excluded from training.
#
# Threshold found:0.024
#
# 351 (4%) doublets called
#
# WSSS_A_KID9383574
#
# subsetting
#
# preprocessing and clustering
#
# Warning message in asMethod(object):
# “sparse->dense coercion: allocating vector of size 1.3 GiB”
# doublet analysis
#
# more than one genotype in channel
#
# 13 clusters
#
# Creating ~5000 artificial doublets...
#
# Dimensional reduction
#
# Evaluating kNN...
#
# Training model...
#
# iter=0, 553 cells excluded from training.
#
# iter=1, 231 cells excluded from training.
#
# Threshold found:0.236
#
# 23 (0.4%) doublets called
#
# WSSS_A_KID9383577
#
# subsetting
#
# preprocessing and clustering
#
# Warning message in asMethod(object):
# “sparse->dense coercion: allocating vector of size 1.5 GiB”
# doublet analysis
#
# more than one genotype in channel
#
# 15 clusters
#
# Creating ~5000 artificial doublets...
#
# Dimensional reduction
#
# Evaluating kNN...
#
# Training model...
#
# iter=0, 504 cells excluded from training.
#
# iter=1, 390 cells excluded from training.
#
# Threshold found:0.052
#
# 197 (3.1%) doublets called
#
# WSSS_A_KID9383578
#
# subsetting
#
# preprocessing and clustering
#
# Warning message in asMethod(object):
# “sparse->dense coercion: allocating vector of size 1.6 GiB”
# doublet analysis
#
# more than one genotype in channel
#
# 16 clusters
#
# Creating ~5000 artificial doublets...
#
# Dimensional reduction
#
# Evaluating kNN...
#
# Training model...
#
# iter=0, 495 cells excluded from training.
#
# iter=1, 367 cells excluded from training.
#
# Threshold found:0.236
#
# 213 (3.3%) doublets called
#
# WSSS_A_KID10063743
#
# subsetting
#
# preprocessing and clustering
#
# doublet analysis
#
# more than one genotype in channel
#
# 15 clusters
#
# Creating ~5000 artificial doublets...
#
# Dimensional reduction
#
# Evaluating kNN...
#
# Training model...
#
# iter=0, 90 cells excluded from training.
#
# iter=1, 51 cells excluded from training.
#
# Threshold found:0.236
#
# 30 (1.2%) doublets called
#
# WSSS_A_KID10063744
#
# subsetting
#
# preprocessing and clustering
#
# doublet analysis
#
# more than one genotype in channel
#
# 20 clusters
#
# Creating ~5000 artificial doublets...
#
# Dimensional reduction
#
# Evaluating kNN...
#
# Training model...
#
# iter=0, 73 cells excluded from training.
#
# iter=1, 50 cells excluded from training.
#
# Threshold found:0.618
#
# 30 (1.4%) doublets called
#
# WSSS_A_KID10063745
#
# subsetting
#
# preprocessing and clustering
#
# doublet analysis
#
# more than one genotype in channel
#
# 15 clusters
#
# Creating ~5000 artificial doublets...
#
# Dimensional reduction
#
# Evaluating kNN...
#
# Training model...
#
# iter=0, 37 cells excluded from training.
#
# iter=1, 32 cells excluded from training.
#
# Threshold found:0.382
#
# 13 (1.1%) doublets called
#
# WSSS_A_KID10063746
#
# subsetting
#
# preprocessing and clustering
#
# doublet analysis
#
# more than one genotype in channel
#
# 18 clusters
#
# Creating ~5000 artificial doublets...
#
# Dimensional reduction
#
# Evaluating kNN...
#
# Training model...
#
# iter=0, 109 cells excluded from training.
#
# iter=1, 73 cells excluded from training.
#
# Threshold found:0.618
#
# 43 (1.7%) doublets called
#
# WSSS_A_KID10063749
#
# subsetting
#
# preprocessing and clustering
#
# Warning message in asMethod(object):
# “sparse->dense coercion: allocating vector of size 1.3 GiB”
# doublet analysis
#
# more than one genotype in channel
#
# 19 clusters
#
# Creating ~5000 artificial doublets...
#
# Dimensional reduction
#
# Evaluating kNN...
#
# Training model...
#
# iter=0, 366 cells excluded from training.
#
# iter=1, 268 cells excluded from training.
#
# Threshold found:0.236
#
# 197 (3.7%) doublets called
#
# WSSS_A_KID10063750
#
# subsetting
#
# preprocessing and clustering
#
# Warning message in asMethod(object):
# “sparse->dense coercion: allocating vector of size 1.2 GiB”
# doublet analysis
#
# more than one genotype in channel
#
# 20 clusters
#
# Creating ~5000 artificial doublets...
#
# Dimensional reduction
#
# Evaluating kNN...
#
# Training model...
#
# iter=0, 368 cells excluded from training.
#
# iter=1, 274 cells excluded from training.
#
# Threshold found:0.382
#
# 195 (3.9%) doublets called
#
# WSSS_A_KID10063841
#
# subsetting
#
# preprocessing and clustering
#
# Warning message in asMethod(object):
# “sparse->dense coercion: allocating vector of size 1.9 GiB”
# doublet analysis
#
# more than one genotype in channel
#
# 11 clusters
#
# Creating ~5000 artificial doublets...
#
# Dimensional reduction
#
# Evaluating kNN...
#
# Training model...
#
# iter=0, 930 cells excluded from training.
#
# iter=1, 767 cells excluded from training.
#
# Threshold found:0.002
#
# 271 (3.4%) doublets called
#
# WSSS_A_KID10063842
#
# subsetting
#
# preprocessing and clustering
#
# Warning message in asMethod(object):
# “sparse->dense coercion: allocating vector of size 2.9 GiB”
# doublet analysis
#
# more than one genotype in channel
#
# 11 clusters
#
# Creating ~6654 artificial doublets...
#
# Dimensional reduction
#
# Evaluating kNN...
#
# Training model...
#
# iter=0, 1769 cells excluded from training.
#
# iter=1, 1259 cells excluded from training.
#
# Threshold found:0.004
#
# 628 (5.2%) doublets called
#
# WSSS_A_KID10063843
#
# subsetting
#
# preprocessing and clustering
#
# Warning message in asMethod(object):
# “sparse->dense coercion: allocating vector of size 2.3 GiB”
# doublet analysis
#
# more than one genotype in channel
#
# 12 clusters
#
# Creating ~5380 artificial doublets...
#
# Dimensional reduction
#
# Evaluating kNN...
#
# Training model...
#
# iter=0, 1146 cells excluded from training.
#
# iter=1, 878 cells excluded from training.
#
# Threshold found:0.003
#
# 408 (4.3%) doublets called
#
# WSSS_A_KID10063839
#
# subsetting
#
# preprocessing and clustering
#
# Warning message in asMethod(object):
# “sparse->dense coercion: allocating vector of size 2.2 GiB”
# doublet analysis
#
# more than one genotype in channel
#
# 18 clusters
#
# Creating ~5406 artificial doublets...
#
# Dimensional reduction
#
# Evaluating kNN...
#
# Training model...
#
# iter=0, 773 cells excluded from training.
#
# iter=1, 606 cells excluded from training.
#
# Threshold found:0.002
#
# 430 (4.6%) doublets called
#
# WSSS_A_KID10063840
#
# subsetting
#
# preprocessing and clustering
#
# Warning message in asMethod(object):
# “sparse->dense coercion: allocating vector of size 1.9 GiB”
# doublet analysis
#
# more than one genotype in channel
#
# 20 clusters
#
# Creating ~5000 artificial doublets...
#
# Dimensional reduction
#
# Evaluating kNN...
#
# Training model...
#
# iter=0, 564 cells excluded from training.
#
# iter=1, 412 cells excluded from training.
#
# Threshold found:0.013
#
# 321 (4%) doublets called
#
# Well_KID10715494
#
# subsetting
#
# preprocessing and clustering
#
# doublet analysis
#
# more than one genotype in channel
#
# 15 clusters
#
# Creating ~5000 artificial doublets...
#
# Dimensional reduction
#
# Evaluating kNN...
#
# Training model...
#
# iter=0, 45 cells excluded from training.
#
# iter=1, 23 cells excluded from training.
#
# Threshold found:0.311
#
# 14 (0.9%) doublets called
#
# Well_KID10715495
#
# subsetting
#
# preprocessing and clustering
#
# doublet analysis
#
# more than one genotype in channel
#
# 13 clusters
#
# Creating ~5000 artificial doublets...
#
# Dimensional reduction
#
# Evaluating kNN...
#
# Training model...
#
# iter=0, 830 cells excluded from training.
#
# iter=1, 771 cells excluded from training.
#
# Threshold found:0.044
#
# 62 (1.6%) doublets called
#
# Well_KID10715496
#
# subsetting
#
# preprocessing and clustering
#
# Warning message in asMethod(object):
# “sparse->dense coercion: allocating vector of size 1.4 GiB”
# doublet analysis
#
# more than one genotype in channel
#
# 17 clusters
#
# Creating ~5000 artificial doublets...
#
# Dimensional reduction
#
# Evaluating kNN...
#
# Training model...
#
# iter=0, 501 cells excluded from training.
#
# iter=1, 421 cells excluded from training.
#
# Threshold found:0.062
#
# 167 (2.8%) doublets called
#
# Well_KID10715497
#
# subsetting
#
# preprocessing and clustering
#
# doublet analysis
#
# more than one genotype in channel
#
# 19 clusters
#
# Creating ~5000 artificial doublets...
#
# Dimensional reduction
#
# Evaluating kNN...
#
# Training model...
#
# iter=0, 190 cells excluded from training.
#
# iter=1, 136 cells excluded from training.
#
# Threshold found:0.31
#
# 67 (1.9%) doublets called
#
# Well_KID10715498
#
# subsetting
#
# preprocessing and clustering
#
# doublet analysis
#
# more than one genotype in channel
#
# 17 clusters
#
# Creating ~5000 artificial doublets...
#
# Dimensional reduction
#
# Evaluating kNN...
#
# Training model...
#
# iter=0, 74 cells excluded from training.
#
# iter=1, 46 cells excluded from training.
#
# Threshold found:0.382
#
# 22 (1.1%) doublets called
#
# KID_CZI13249517
#
# subsetting
#
# preprocessing and clustering
#
# Warning message in asMethod(object):
# “sparse->dense coercion: allocating vector of size 1.8 GiB”
# doublet analysis
#
# only one genotype in channel
#
# 27 clusters
#
# Creating ~7290 artificial doublets...
#
# Dimensional reduction
#
# Evaluating kNN...
#
# Training model...
#
# iter=0, 479 cells excluded from training.
#
# iter=1, 319 cells excluded from training.
#
# Threshold found:0.029
#
# 309 (4.1%) doublets called
#
# KID_CZI13249518
#
# subsetting
#
# preprocessing and clustering
#
# doublet analysis
#
# only one genotype in channel
#
# 8 clusters
#
# Creating ~5000 artificial doublets...
#
# Dimensional reduction
#
# Evaluating kNN...
#
# Training model...
#
# iter=0, 3 cells excluded from training.
#
# iter=1, 1 cells excluded from training.
#
# Threshold found:0.594
#
# 1 (0.2%) doublets called
#
# KID_CZI13249519
#
# subsetting
#
# preprocessing and clustering
#
# Warning message in asMethod(object):
# “sparse->dense coercion: allocating vector of size 2.1 GiB”
# doublet analysis
#
# only one genotype in channel
#
# 18 clusters
#
# Creating ~5192 artificial doublets...
#
# Dimensional reduction
#
# Evaluating kNN...
#
# Training model...
#
# iter=0, 601 cells excluded from training.
#
# iter=1, 438 cells excluded from training.
#
# Threshold found:0.016
#
# 403 (4.7%) doublets called
#
# KID_CZI13249520
#
# subsetting
#
# preprocessing and clustering
#
# doublet analysis
#
# only one genotype in channel
#
# 11 clusters
#
# Creating ~5000 artificial doublets...
#
# Dimensional reduction
#
# Evaluating kNN...
#
# Training model...
#
# iter=0, 2 cells excluded from training.
#
# iter=1, 1 cells excluded from training.
#
# Threshold found:0.382
#
# 1 (0.3%) doublets called
#
# KID_CZI13249521
#
# subsetting
#
# preprocessing and clustering
#
# Warning message in asMethod(object):
# “sparse->dense coercion: allocating vector of size 1.4 GiB”
# doublet analysis
#
# only one genotype in channel
#
# 23 clusters
#
# Creating ~5290 artificial doublets...
#
# Dimensional reduction
#
# Evaluating kNN...
#
# Training model...
#
# iter=0, 405 cells excluded from training.
#
# iter=1, 9 cells excluded from training.
#
# Threshold found:0.618
#
# 3 (0.1%) doublets called
#
# KID_CZI13249522
#
# subsetting
#
# preprocessing and clustering
#
# Warning message in asMethod(object):
# “sparse->dense coercion: allocating vector of size 2.0 GiB”
# doublet analysis
#
# only one genotype in channel
#
# 25 clusters
#
# Creating ~6250 artificial doublets...
#
# Dimensional reduction
#
# Evaluating kNN...
#
# Training model...
#
# iter=0, 791 cells excluded from training.
#
# iter=1, 10 cells excluded from training.
#
# Threshold found:0.236
#
# 4 (0%) doublets called
#
# KID_CZI13249523
#
# subsetting
#
# preprocessing and clustering
#
# Warning message in asMethod(object):
# “sparse->dense coercion: allocating vector of size 1.6 GiB”
# doublet analysis
#
# only one genotype in channel
#
# 17 clusters
#
# Creating ~5000 artificial doublets...
#
# Dimensional reduction
#
# Evaluating kNN...
#
# Training model...
#
# iter=0, 506 cells excluded from training.
#
# iter=1, 235 cells excluded from training.
#
# Threshold found:0.236
#
# 107 (1.6%) doublets called
#
# KID_CZI13249524
#
# subsetting
#
# preprocessing and clustering
#
# Warning message in asMethod(object):
# “sparse->dense coercion: allocating vector of size 1.9 GiB”
# doublet analysis
#
# only one genotype in channel
#
# 16 clusters
#
# Creating ~5000 artificial doublets...
#
# Dimensional reduction
#
# Evaluating kNN...
#
# Training model...
#
# iter=0, 744 cells excluded from training.
#
# iter=1, 9 cells excluded from training.
#
# Threshold found:0.382
#
# 4 (0%) doublets called
#
# KID_CZI13249525
#
# subsetting
#
# preprocessing and clustering
#
# Warning message in asMethod(object):
# “sparse->dense coercion: allocating vector of size 1.2 GiB”
# doublet analysis
#
# more than one genotype in channel
#
# 22 clusters
#
# Creating ~5000 artificial doublets...
#
# Dimensional reduction
#
# Evaluating kNN...
#
# Training model...
#
# iter=0, 507 cells excluded from training.
#
# iter=1, 378 cells excluded from training.
#
# Threshold found:0.057
#
# 115 (2.4%) doublets called
#
# KID_CZI13249527
#
# subsetting
#
# preprocessing and clustering
#
# Warning message in asMethod(object):
# “sparse->dense coercion: allocating vector of size 2.6 GiB”
# doublet analysis
#
# more than one genotype in channel
#
# 25 clusters
#
# Creating ~6250 artificial doublets...
#
# Dimensional reduction
#
# Evaluating kNN...
#
# Training model...
#
# iter=0, 1385 cells excluded from training.
#
# iter=1, 1074 cells excluded from training.
#
# Threshold found:0.009
#
# 539 (5%) doublets called
#
# KID_CZI13249528
#
# subsetting
#
# preprocessing and clustering
#
# Warning message in asMethod(object):
# “sparse->dense coercion: allocating vector of size 2.2 GiB”
# doublet analysis
#
# more than one genotype in channel
#
# 21 clusters
#
# Creating ~5483 artificial doublets...
#
# Dimensional reduction
#
# Evaluating kNN...
#
# Training model...
#
# iter=0, 626 cells excluded from training.
#
# iter=1, 598 cells excluded from training.
#
# Threshold found:0.004
#
# 431 (4.6%) doublets called
#
# KID_CZI13249529
#
# subsetting
#
# preprocessing and clustering
#
# Warning message in asMethod(object):
# “sparse->dense coercion: allocating vector of size 1.3 GiB”
# doublet analysis
#
# more than one genotype in channel
#
# 21 clusters
#
# Creating ~5000 artificial doublets...
#
# Dimensional reduction
#
# Evaluating kNN...
#
# Training model...
#
# iter=0, 364 cells excluded from training.
#
# iter=1, 220 cells excluded from training.
#
# Threshold found:0.008
#
# 157 (2.9%) doublets called
#
# KID_CZI13249530
#
# subsetting
#
# preprocessing and clustering
#
# Warning message in asMethod(object):
# “sparse->dense coercion: allocating vector of size 1.8 GiB”
# doublet analysis
#
# more than one genotype in channel
#
# 24 clusters
#
# Creating ~5760 artificial doublets...
#
# Dimensional reduction
#
# Evaluating kNN...
#
# Training model...
#
# iter=0, 640 cells excluded from training.
#
# iter=1, 429 cells excluded from training.
#
# Threshold found:0.012
#
# 299 (3.9%) doublets called
#
# KID_CZI13249531
#
# subsetting
#
# preprocessing and clustering
#
# Warning message in asMethod(object):
# “sparse->dense coercion: allocating vector of size 1.4 GiB”
# doublet analysis
#
# more than one genotype in channel
#
# 24 clusters
#
# Creating ~5760 artificial doublets...
#
# Dimensional reduction
#
# Evaluating kNN...
#
# Training model...
#
# iter=0, 710 cells excluded from training.
#
# iter=1, 536 cells excluded from training.
#
# Threshold found:0.029
#
# 157 (2.7%) doublets called
#
# KID_CZI13249532
#
# subsetting
#
# preprocessing and clustering
#
# Warning message in asMethod(object):
# “sparse->dense coercion: allocating vector of size 1.1 GiB”
# doublet analysis
#
# more than one genotype in channel
#
# 24 clusters
#
# Creating ~5760 artificial doublets...
#
# Dimensional reduction
#
# Evaluating kNN...
#
# Training model...
#
# iter=0, 335 cells excluded from training.
#
# iter=1, 244 cells excluded from training.
#
# Threshold found:0.038
#
# 104 (2.3%) doublets called

# %%
adata$obs = cbind(adata$obs, do.call(rbind, doublet_df))

# %%
#keep the doublets in for now
#adata = adata[adata$obs$dblf_cuts %in% "singlet"]
#adata = adata[adata$obs$status %in% "singlet"]

# %%
#write out
adata$write_h5ad("data/raw/10X_3p/healthy_raw.h5ad")

# %%
sessionInfo()
# Out:
# R version 4.0.4 (2021-02-15)
# Platform: x86_64-pc-linux-gnu (64-bit)
# Running under: Ubuntu 20.04.1 LTS
#
# Matrix products: default
# BLAS:   /usr/lib/x86_64-linux-gnu/blas/libblas.so.3.9.0
# LAPACK: /usr/lib/x86_64-linux-gnu/lapack/liblapack.so.3.9.0
#
# locale:
#  [1] LC_CTYPE=en_US.UTF-8       LC_NUMERIC=C
#  [3] LC_TIME=en_US.UTF-8        LC_COLLATE=en_US.UTF-8
#  [5] LC_MONETARY=en_US.UTF-8    LC_MESSAGES=en_US.UTF-8
#  [7] LC_PAPER=en_US.UTF-8       LC_NAME=C
#  [9] LC_ADDRESS=C               LC_TELEPHONE=C
# [11] LC_MEASUREMENT=en_US.UTF-8 LC_IDENTIFICATION=C
#
# attached base packages:
# [1] parallel  stats4    stats     graphics  grDevices utils     datasets
# [8] methods   base
#
# other attached packages:
#  [1] scDblFinder_1.7.2           MASS_7.3-53.1
#  [3] ggrastr_1.0.1               paletteer_1.4.1
#  [5] pbapply_1.7-0               SoupX_1.5.2
#  [7] igraph_1.2.6                DropletUtils_1.10.3
#  [9] pheatmap_1.0.12             cowplot_1.1.1
# [11] scater_1.18.6               ggplot2_3.4.1
# [13] scran_1.18.5                SingleCellExperiment_1.12.0
# [15] SummarizedExperiment_1.20.0 Biobase_2.50.0
# [17] GenomicRanges_1.42.0        GenomeInfoDb_1.26.7
# [19] IRanges_2.24.1              S4Vectors_0.28.1
# [21] BiocGenerics_0.36.1         MatrixGenerics_1.2.1
# [23] matrixStats_0.63.0          reticulate_1.28
#
# loaded via a namespace (and not attached):
#   [1] uuid_0.1-4                plyr_1.8.8
#   [3] repr_1.1.3                lazyeval_0.2.2
#   [5] sp_1.6-0                  splines_4.0.4
#   [7] BiocParallel_1.24.1       listenv_0.9.0
#   [9] scattermore_0.8           digest_0.6.31
#  [11] htmltools_0.5.4           viridis_0.6.2
#  [13] fansi_1.0.4               magrittr_2.0.3
#  [15] tensor_1.5                cluster_2.1.1
#  [17] ROCR_1.0-11               limma_3.46.0
#  [19] globals_0.16.2            R.utils_2.12.2
#  [21] spatstat.sparse_3.0-0     colorspace_2.1-0
#  [23] ggrepel_0.9.3             dplyr_1.1.0
#  [25] crayon_1.5.2              RCurl_1.98-1.10
#  [27] jsonlite_1.8.4            spatstat.data_3.0-0
#  [29] progressr_0.13.0          survival_3.2-10
#  [31] zoo_1.8-11                glue_1.6.2
#  [33] polyclip_1.10-4           gtable_0.3.1
#  [35] zlibbioc_1.36.0           XVector_0.30.0
#  [37] leiden_0.3.9              DelayedArray_0.16.3
#  [39] BiocSingular_1.6.0        Rhdf5lib_1.12.1
#  [41] future.apply_1.10.0       HDF5Array_1.18.1
#  [43] abind_1.4-5               scales_1.2.1
#  [45] edgeR_3.32.1              spatstat.random_3.1-3
#  [47] miniUI_0.1.1.1            Rcpp_1.0.10
#  [49] viridisLite_0.4.1         xtable_1.8-4
#  [51] dqrng_0.3.0               rsvd_1.0.5
#  [53] htmlwidgets_1.6.1         httr_1.4.4
#  [55] RColorBrewer_1.1-3        ellipsis_0.3.2.9000
#  [57] Seurat_4.3.0              ica_1.0-3
#  [59] farver_2.1.1              pkgconfig_2.0.3
#  [61] R.methodsS3_1.8.2         scuttle_1.0.4
#  [63] uwot_0.1.14               deldir_1.0-6
#  [65] locfit_1.5-9.4            utf8_1.2.3
#  [67] labeling_0.4.2            reshape2_1.4.4
#  [69] tidyselect_1.2.0          rlang_1.0.6
#  [71] later_1.3.0               munsell_0.5.0
#  [73] tools_4.0.4               xgboost_1.5.2.1
#  [75] cli_3.6.0                 generics_0.1.3
#  [77] ggridges_0.5.4            stringr_1.5.0
#  [79] evaluate_0.20             fastmap_1.1.0
#  [81] goftest_1.2-3             rematch2_2.1.2
#  [83] fitdistrplus_1.1-8        purrr_1.0.1
#  [85] RANN_2.6.1                nlme_3.1-152
#  [87] future_1.31.0             sparseMatrixStats_1.2.1
#  [89] mime_0.12                 R.oo_1.25.0
#  [91] compiler_4.0.4            beeswarm_0.3.1
#  [93] plotly_4.10.1             png_0.1-8
#  [95] spatstat.utils_3.0-1      tibble_3.1.8
#  [97] statmod_1.4.35            stringi_1.7.12
#  [99] lattice_0.20-41           bluster_1.0.0
# [101] IRdisplay_1.0             Matrix_1.5-3
# [103] vctrs_0.5.2               pillar_1.8.1
# [105] lifecycle_1.0.3           rhdf5filters_1.2.1
# [107] spatstat.geom_3.0-6       lmtest_0.9-40
# [109] RcppAnnoy_0.0.20          BiocNeighbors_1.8.2
# [111] data.table_1.14.6         bitops_1.0-7
# [113] irlba_2.3.5.1             httpuv_1.6.8
# [115] patchwork_1.1.2           R6_2.5.1
# [117] promises_1.2.0.1          KernSmooth_2.23-18
# [119] gridExtra_2.3             vipor_0.4.5
# [121] parallelly_1.34.0         codetools_0.2-18
# [123] rhdf5_2.34.0              withr_2.5.0
# [125] SeuratObject_4.1.3        sctransform_0.3.5
# [127] GenomeInfoDbData_1.2.4    grid_4.0.4
# [129] beachmat_2.6.4            IRkernel_1.1.1
# [131] tidyr_1.3.0               DelayedMatrixStats_1.12.3
# [133] Cairo_1.6-0               Rtsne_0.16
# [135] spatstat.explore_3.0-6    pbdZMQ_0.3-5
# [137] getPass_0.2-2             shiny_1.7.4
# [139] base64enc_0.1-3           ggbeeswarm_0.6.0
