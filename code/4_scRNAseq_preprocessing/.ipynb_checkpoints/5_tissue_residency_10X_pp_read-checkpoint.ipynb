# %%
project_dir = "~/ben_lustre/current_projects/kidney_glomTI_response"
setwd(project_dir)
suppressPackageStartupMessages(source("https://raw.githubusercontent.com/bjstewart1/helpful_singlecell/main/functions.R"))
ad <- import("anndata")
sc <- import("scanpy")
scv <- import("scvelo")
sp = import("scipy")
# Out:
# Warning message:
# “The `size` argument of `element_rect()` is deprecated as of ggplot2 3.4.0.
# ℹ Please use the `linewidth` argument instead.”

# %%
py_config()
# Out:
# python:         /home/jovyan/my-conda-envs/myenv/bin/python
# libpython:      /home/jovyan/my-conda-envs/myenv/lib/libpython3.8.so
# pythonhome:     /home/jovyan/my-conda-envs/myenv:/home/jovyan/my-conda-envs/myenv
# version:        3.8.8 | packaged by conda-forge | (default, Feb 20 2021, 16:22:27)  [GCC 9.3.0]
# numpy:          /home/jovyan/my-conda-envs/myenv/lib/python3.8/site-packages/numpy
# numpy_version:  1.20.3
#
# NOTE: Python version was forced by RETICULATE_PYTHON

# %%
tenx_dir <- "./data/seq_data/10X_3p"
sequencing_inventory <- read.csv("/nfs/team297/bs16/sample_donor_data/sequencing_inventory.csv", check.names = FALSE)
sequencing_inventory <- sequencing_inventory[sequencing_inventory$experiment %in% c("10X_3'_V3") & #just 3p
                                           sequencing_inventory$cellranger_SOC %in% 'TRUE' & sequencing_inventory$poor_QC %in% "FALSE",]
#exclude fetal - these are one per channel and we will analyse these elsewhere
sequencing_inventory <- sequencing_inventory[!sequencing_inventory$tissue %in% grep("fetal", sequencing_inventory$tissue, value = TRUE), ]
#remove perfusion samples
perfusion_batches = c("Batch_9", "Batch_12", "Batch_14")
sequencing_inventory = sequencing_inventory[!sequencing_inventory$tissue_dissociation_processing_batch %in% perfusion_batches, ]
#fix the irods spaces
sequencing_inventory$irods_ID <- gsub(" ", "", sequencing_inventory$irods_ID)

#make a set of channels and files
fn_in <- data.frame("channel" = sequencing_inventory$sanger_ID, "filename" = sequencing_inventory$irods_ID)

#now get the assignments
cell_assignments <- readRDS(file.path(project_dir,  "data/genotypes/cell_assignments_cells.RDS"))

# %%
#now read it all in
dir <- "/lustre/scratch126/cellgen/team297/bs16/current_projects/kidney_glomTI_response/data/seq_data/10X_3p"
adata_list <- lapply(1:nrow(fn_in), function(x){
    message("***====================***")
    message(paste0(x/nrow(fn_in)*100, "%"))
    start_time <- Sys.time()
    f <- fn_in[x, "filename"]
    ch <- fn_in[x, "channel"]
    message("sample ", ch)
#read in adata
    message("reading in adata")
    #adata <- afh$anndata_from_h5(file.path(dir, f, "cellbender_corrected_filtered.h5"))   
    #adata$var_names_make_unique()
    #orig_adata <- sc$read_10x_h5(file.path(dir, f,  "filtered_feature_bc_matrix.h5" ))
    adata <- sc$read_h5ad(file.path(dir, f, "scAR_denoised.h5ad"))
    adata$var_names_make_unique()
    adata$obs$barcode <- adata$obs_names$values
    adata$obs$channel <- ch #add the channel name
   #make the denoised counts a sparse layer.
    adata$layers = list("denoised_counts" = sp$sparse$csr_matrix(adata$layers['denoised_counts']),
                        "raw_counts" = adata$layers['raw_counts']
                       ) #this will help with memory probably
#add genotyping assignments
    message("adding genotyping assignments")
    assignments <- cell_assignments[cell_assignments$channel %in% ch, c(2,3, 5,6)] #these are ordered as per the barcode file
    adata$obs <- cbind(adata$obs, assignments)
    
#sort out the metadata
        message("adding metadata")
        metadata = sequencing_inventory
        rownames(metadata) <- metadata$sanger_ID
        adata$obs <- cbind(adata$obs, metadata[adata$obs$channel, ])
    
    
#add in some donor demographics ####    
    message("adding demographics")
    donor_demographics <- read.csv("~/ben_nfs/sample_donor_data/donor_demographics.csv", row.names = 1)
    donor_demographics <- donor_demographics[adata$obs$genotype, ]
    adata$obs <- cbind(adata$obs, donor_demographics) #bind this to adata$obs - this will result in NAs but we will remove the doublets in due cours

#add the velocyto data
    message("adding velocyto")
    ldata = scv$read(file.path(dir, f, 'velocyto', paste0(f, '.loom')))
    #fix up the loom names
    loom_names = gsub(f, "", ldata$obs_names$values)
    loom_names = gsub(":", "", loom_names)
    loom_names = gsub("x", "-1", loom_names)
    ldata$obs_names = paste0(loom_names, "_",  f)
    #merge
    adata = scv$utils$merge(adata, ldata)
    rm(ldata)
    gc() #clean
#return the adata
    message("sample ", ch, " done")
    message("====================")
        #time
    end_time <- Sys.time()
    time =  end_time - start_time
    message(paste(time, 'seconds'))
    message("***====================***")

return(adata)
})
adata <- sc$concat(adata_list)
vr <- adata_list[[1]]$var
# Out:
# ***====================***
#
# 2.08333333333333%
#
# sample CG_SB_NB8768284
#
# reading in adata
#
# adding genotyping assignments
#
# adding metadata
#
# adding demographics
#
# adding velocyto
#
# sample CG_SB_NB8768284 done
#
# ====================
#
# 20.0863261222839 seconds
#
# ***====================***
#
# ***====================***
#
# 4.16666666666667%
#
# sample WSSS_A_KID9369817
#
# reading in adata
#
# adding genotyping assignments
#
# adding metadata
#
# adding demographics
#
# adding velocyto
#
# sample WSSS_A_KID9369817 done
#
# ====================
#
# 58.5618648529053 seconds
#
# ***====================***
#
# ***====================***
#
# 6.25%
#
# sample WSSS_A_KID9369818
#
# reading in adata
#
# adding genotyping assignments
#
# adding metadata
#
# adding demographics
#
# adding velocyto
#
# sample WSSS_A_KID9369818 done
#
# ====================
#
# 53.1012592315674 seconds
#
# ***====================***
#
# ***====================***
#
# 8.33333333333333%
#
# sample WSSS_A_KID9369819
#
# reading in adata
#
# adding genotyping assignments
#
# adding metadata
#
# adding demographics
#
# adding velocyto
#
# sample WSSS_A_KID9369819 done
#
# ====================
#
# 59.6246421337128 seconds
#
# ***====================***
#
# ***====================***
#
# 10.4166666666667%
#
# sample WSSS_A_KID9369820
#
# reading in adata
#
# adding genotyping assignments
#
# adding metadata
#
# adding demographics
#
# adding velocyto
#
# sample WSSS_A_KID9369820 done
#
# ====================
#
# 58.8093395233154 seconds
#
# ***====================***
#
# ***====================***
#
# 12.5%
#
# sample WSSS_A_KID9369821
#
# reading in adata
#
# adding genotyping assignments
#
# adding metadata
#
# adding demographics
#
# adding velocyto
#
# sample WSSS_A_KID9369821 done
#
# ====================
#
# 1.93324868679047 seconds
#
# ***====================***
#
# ***====================***
#
# 14.5833333333333%
#
# sample WSSS_A_KID9383375
#
# reading in adata
#
# sample Well_KID10715496 done
#
# ====================
#
# 47.8265991210938 seconds
#
# ***====================***
#
# ***====================***
#
# 66.6666666666667%
#
# sample Well_KID10715497
#
# reading in adata
#
# adding genotyping assignments
#
# adding metadata
#
# adding demographics
#
# adding velocyto
#
# sample Well_KID10715497 done
#
# ====================
#
# 27.4670579433441 seconds
#
# ***====================***
#
# ***====================***
#
# 68.75%
#
# sample Well_KID10715498
#
# reading in adata
#
# adding genotyping assignments
#
# adding metadata
#
# adding demographics
#
# adding velocyto
#
# sample Well_KID10715498 done
#
# ====================
#
# 23.3502876758575 seconds
#
# ***====================***
#
# ***====================***
#
# 70.8333333333333%
#
# sample KID_CZI13249517
#
# reading in adata
#
# adding genotyping assignments
#
# adding metadata
#
# adding demographics
#
# adding velocyto
#
# sample KID_CZI13249517 done
#
# ====================
#
# 1.17909582853317 seconds
#
# ***====================***
#
# ***====================***
#
# 72.9166666666667%
#
# sample KID_CZI13249518
#
# reading in adata
#
# adding genotyping assignments
#
# adding metadata
#
# adding demographics
#
# adding velocyto
#
# sample KID_CZI13249518 done
#
# ====================
#
# 4.98729538917542 seconds
#
# ***====================***
#
# ***====================***
#
# 75%
#
# sample KID_CZI13249519
#
# reading in adata
#
# adding genotyping assignments
#
# adding metadata
#
# adding demographics
#
# adding velocyto
#
# sample KID_CZI13249519 done
#
# ====================
#
# 1.0351088086764 seconds
#
# ***====================***
#
# ***====================***
#
# 77.0833333333333%
#
# sample KID_CZI13249520
#
# reading in adata
#
# adding genotyping assignments
#
# adding metadata
#
# adding demographics
#
# adding velocyto
#
# sample KID_CZI13249520 done
#
# ====================
#
# 4.47489881515503 seconds
#
# ***====================***
#
# ***====================***
#
# 79.1666666666667%
#
# sample KID_CZI13249521
#
# reading in adata
#
# adding genotyping assignments
#
# adding metadata
#
# adding demographics
#
# adding velocyto
#
# sample KID_CZI13249521 done
#
# ====================
#
# 47.7436892986298 seconds
#
# ***====================***
#
# ***====================***
#
# 81.25%
#
# sample KID_CZI13249522
#
# reading in adata
#
# adding genotyping assignments
#
# adding metadata
#
# adding demographics
#
# adding velocyto
#
# sample KID_CZI13249522 done
#
# ====================
#
# 1.20854376157125 seconds
#
# ***====================***
#
# ***====================***
#
# 83.3333333333333%
#
# sample KID_CZI13249523
#
# reading in adata
#
# adding genotyping assignments
#
# adding metadata
#
# adding demographics
#
# adding velocyto
#
# sample KID_CZI13249523 done
#
# ====================
#
# 55.3610756397247 seconds
#
# ***====================***
#
# ***====================***
#
# 85.4166666666667%
#
# sample KID_CZI13249524
#
# reading in adata
#
# adding genotyping assignments
#
# adding metadata
#
# adding demographics
#
# adding velocyto
#
# sample KID_CZI13249524 done
#
# ====================
#
# 1.16308966875076 seconds
#
# ***====================***
#
# ***====================***
#
# 87.5%
#
# sample KID_CZI13249525
#
# reading in adata
#
# adding genotyping assignments
#
# adding metadata
#
# adding demographics
#
# adding velocyto
#
# sample KID_CZI13249525 done
#
# ====================
#
# 41.0355114936829 seconds
#
# ***====================***
#
# ***====================***
#
# 89.5833333333333%
#
# sample KID_CZI13249527
#
# reading in adata
#
# adding genotyping assignments
#
# adding metadata
#
# adding demographics
#
# adding velocyto
#
# sample KID_CZI13249527 done
#
# ====================
#
# 1.5799675265948 seconds
#
# ***====================***
#
# ***====================***
#
# 91.6666666666667%
#
# sample KID_CZI13249528
#
# reading in adata
#
# adding genotyping assignments
#
# adding metadata
#
# adding demographics
#
# adding velocyto
#
# sample KID_CZI13249528 done
#
# ====================
#
# 1.42685612042745 seconds
#
# ***====================***
#
# ***====================***
#
# 93.75%
#
# sample KID_CZI13249529
#
# reading in adata
#
# adding genotyping assignments
#
# adding metadata
#
# adding demographics
#
# adding velocyto
#
# sample KID_CZI13249529 done
#
# ====================
#
# 58.7329061031342 seconds
#
# ***====================***
#
# ***====================***
#
# 95.8333333333333%
#
# sample KID_CZI13249530
#
# reading in adata
#
# adding genotyping assignments
#
# adding metadata
#
# adding demographics
#
# adding velocyto
#
# sample KID_CZI13249530 done
#
# ====================
#
# 1.26886553764343 seconds
#
# ***====================***
#
# ***====================***
#
# 97.9166666666667%
#
# sample KID_CZI13249531
#
# reading in adata
#
# adding genotyping assignments
#
# adding metadata
#
# adding demographics
#
# adding velocyto
#
# sample KID_CZI13249531 done
#
# ====================
#
# 58.5031354427338 seconds
#
# ***====================***
#
# ***====================***
#
# 100%
#
# sample KID_CZI13249532
#
# reading in adata
#
# adding genotyping assignments
#
# adding metadata
#
# adding demographics
#
# adding velocyto
#
# sample KID_CZI13249532 done
#
# ====================
#
# 47.6271138191223 seconds
#
# ***====================***

# %%
#concatenate these data
adata <- sc$concat(adata_list)
vr <- adata_list[[1]]$var

# %%
#sort out symbol etc..
adata$var$ID <- vr$gene_ids
adata$var$Symbol <- rownames(vr)

# %%
adata$write_h5ad("data/raw/10X_3p/healthy_raw_pre_QC.h5ad")

# %%
sessionInfo()
# Out:
# R version 4.0.4 (2021-02-15)
# Platform: x86_64-pc-linux-gnu (64-bit)
# Running under: Ubuntu 20.04.1 LTS
#
# Matrix products: default
# BLAS:   /usr/lib/x86_64-linux-gnu/blas/libblas.so.3.9.0
# LAPACK: /usr/lib/x86_64-linux-gnu/lapack/liblapack.so.3.9.0
#
# locale:
#  [1] LC_CTYPE=en_US.UTF-8       LC_NUMERIC=C
#  [3] LC_TIME=en_US.UTF-8        LC_COLLATE=en_US.UTF-8
#  [5] LC_MONETARY=en_US.UTF-8    LC_MESSAGES=en_US.UTF-8
#  [7] LC_PAPER=en_US.UTF-8       LC_NAME=C
#  [9] LC_ADDRESS=C               LC_TELEPHONE=C
# [11] LC_MEASUREMENT=en_US.UTF-8 LC_IDENTIFICATION=C
#
# attached base packages:
# [1] parallel  stats4    stats     graphics  grDevices utils     datasets
# [8] methods   base
#
# other attached packages:
#  [1] paletteer_1.4.1             pbapply_1.7-0
#  [3] SoupX_1.5.2                 igraph_1.2.6
#  [5] DropletUtils_1.10.3         pheatmap_1.0.12
#  [7] cowplot_1.1.1               scater_1.18.6
#  [9] ggplot2_3.4.1               scran_1.18.5
# [11] SingleCellExperiment_1.12.0 SummarizedExperiment_1.20.0
# [13] Biobase_2.50.0              GenomicRanges_1.42.0
# [15] GenomeInfoDb_1.26.7         IRanges_2.24.1
# [17] S4Vectors_0.28.1            BiocGenerics_0.36.1
# [19] MatrixGenerics_1.2.1        matrixStats_0.63.0
# [21] reticulate_1.28
#
# loaded via a namespace (and not attached):
#   [1] uuid_0.1-4                plyr_1.8.8
#   [3] repr_1.1.3                lazyeval_0.2.2
#   [5] sp_1.6-0                  splines_4.0.4
#   [7] BiocParallel_1.24.1       listenv_0.9.0
#   [9] scattermore_0.8           digest_0.6.31
#  [11] htmltools_0.5.4           viridis_0.6.2
#  [13] fansi_1.0.4               magrittr_2.0.3
#  [15] tensor_1.5                cluster_2.1.1
#  [17] ROCR_1.0-11               limma_3.46.0
#  [19] globals_0.16.2            R.utils_2.12.2
#  [21] spatstat.sparse_3.0-0     colorspace_2.1-0
#  [23] ggrepel_0.9.3             dplyr_1.1.0
#  [25] crayon_1.5.2              RCurl_1.98-1.10
#  [27] jsonlite_1.8.4            spatstat.data_3.0-0
#  [29] progressr_0.13.0          survival_3.2-10
#  [31] zoo_1.8-11                glue_1.6.2
#  [33] polyclip_1.10-4           gtable_0.3.1
#  [35] zlibbioc_1.36.0           XVector_0.30.0
#  [37] leiden_0.3.9              DelayedArray_0.16.3
#  [39] BiocSingular_1.6.0        Rhdf5lib_1.12.1
#  [41] future.apply_1.10.0       HDF5Array_1.18.1
#  [43] abind_1.4-5               scales_1.2.1
#  [45] edgeR_3.32.1              spatstat.random_3.1-3
#  [47] miniUI_0.1.1.1            Rcpp_1.0.10
#  [49] viridisLite_0.4.1         xtable_1.8-4
#  [51] dqrng_0.3.0               rsvd_1.0.5
#  [53] htmlwidgets_1.6.1         httr_1.4.4
#  [55] RColorBrewer_1.1-3        ellipsis_0.3.2.9000
#  [57] Seurat_4.3.0              ica_1.0-3
#  [59] pkgconfig_2.0.3           R.methodsS3_1.8.2
#  [61] scuttle_1.0.4             uwot_0.1.14
#  [63] deldir_1.0-6              locfit_1.5-9.4
#  [65] utf8_1.2.3                reshape2_1.4.4
#  [67] tidyselect_1.2.0          rlang_1.0.6
#  [69] later_1.3.0               munsell_0.5.0
#  [71] tools_4.0.4               cli_3.6.0
#  [73] generics_0.1.3            ggridges_0.5.4
#  [75] stringr_1.5.0             evaluate_0.20
#  [77] fastmap_1.1.0             goftest_1.2-3
#  [79] rematch2_2.1.2            fitdistrplus_1.1-8
#  [81] purrr_1.0.1               RANN_2.6.1
#  [83] nlme_3.1-152              future_1.31.0
#  [85] sparseMatrixStats_1.2.1   mime_0.12
#  [87] R.oo_1.25.0               compiler_4.0.4
#  [89] beeswarm_0.3.1            plotly_4.10.1
#  [91] png_0.1-8                 spatstat.utils_3.0-1
#  [93] tibble_3.1.8              statmod_1.4.35
#  [95] stringi_1.7.12            lattice_0.20-41
#  [97] bluster_1.0.0             IRdisplay_1.0
#  [99] Matrix_1.5-3              vctrs_0.5.2
# [101] pillar_1.8.1              lifecycle_1.0.3
# [103] rhdf5filters_1.2.1        spatstat.geom_3.0-6
# [105] lmtest_0.9-40             RcppAnnoy_0.0.20
# [107] BiocNeighbors_1.8.2       data.table_1.14.6
# [109] bitops_1.0-7              irlba_2.3.5.1
# [111] httpuv_1.6.8              patchwork_1.1.2
# [113] R6_2.5.1                  promises_1.2.0.1
# [115] KernSmooth_2.23-18        gridExtra_2.3
# [117] vipor_0.4.5               parallelly_1.34.0
# [119] codetools_0.2-18          MASS_7.3-53.1
# [121] rhdf5_2.34.0              withr_2.5.0
# [123] SeuratObject_4.1.3        sctransform_0.3.5
# [125] GenomeInfoDbData_1.2.4    grid_4.0.4
# [127] beachmat_2.6.4            IRkernel_1.1.1
# [129] tidyr_1.3.0               DelayedMatrixStats_1.12.3
# [131] Rtsne_0.16                spatstat.explore_3.0-6
# [133] pbdZMQ_0.3-5              getPass_0.2-2
# [135] shiny_1.7.4               base64enc_0.1-3
# [137] ggbeeswarm_0.6.0
