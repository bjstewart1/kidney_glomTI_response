# %%
library(Seurat)
library(SeuratDisk)
# Out:
# Attaching SeuratObject
#
# Attaching sp
#
# Registered S3 method overwritten by 'SeuratDisk':
#   method            from
#   as.sparse.H5Group Seurat

# %%
setwd("~/ben_lustre/current_projects/kidney_glomTI_response")

# %%
file =  SeuratDisk::LoadH5Seurat("data/public_data/kpmp_2022/521c5b34-3dd0-4871-8064-61d3e3f1775a_PREMIERE_Alldatasets_08132021.h5Seurat")
# Out:
# Validating h5Seurat file
#
# Initializing RNA with data
#
# Adding counts for RNA
#
# Adding scale.data for RNA
#
# Adding feature-level metadata for RNA
#
# Adding variable feature information for RNA
#
# Adding reduction harmony
#
# Adding cell embeddings for harmony
#
# Adding feature loadings for harmony
#
# Adding projected loadings for harmony
#
# Adding miscellaneous information for harmony
#
# Adding reduction pca
#
# Adding cell embeddings for pca
#
# Adding feature loadings for pca
#
# Adding miscellaneous information for pca
#
# Adding reduction umap
#
# Adding cell embeddings for umap
#
# Adding miscellaneous information for umap
#
# Adding command information
#
# Adding cell-level metadata
#
# Adding miscellaneous information
#
# Adding tool-specific results

# %%
DimPlot(file, reduction = "umap")
# Out:
# Rasterizing points since number of points exceeds 100,000.
# To disable this behavior set `raster=FALSE`
# plot without title

# %%
sceasy::convertFormat(file, from="seurat", to="anndata",
                       outFile='data/public_data/kpmp.h5ad')
# Out:
# AnnData object with n_obs × n_vars = 110346 × 30395
#     obs: 'orig.ident', 'nCount_RNA', 'nFeature_RNA', 'percent.mt', 'subclass.l2', 'subclass.l1', 'dataSource', 'sampletype', 'umap1', 'umap2', 'SpecimenID', 'diseasetype', 'ClusterNumber', 'ClusterClass', 'LibraryID', 'age', 'seurat_clusters', 'gender', 'state', 'tissuetype', 'celltype'
#     var: 'vst.mean', 'vst.variance', 'vst.variance.expected', 'vst.variance.standardized', 'vst.variable'
#     obsm: 'X_harmony', 'X_pca', 'X_umap'

# %%
head(file@meta.data)
# Out:
#                               orig.ident nCount_RNA nFeature_RNA percent.mt
# AKI3010018_AAACCCACAGGGATAC-1 AKI3010018  2267.5106 1281         12.896985
# AKI3010018_AAACCCATCTGATGGT-1 AKI3010018  1346.9072  893         12.222007
# AKI3010018_AAACCCATCTGCTTTA-1 AKI3010018  1309.4176  720         33.350350
# AKI3010018_AAACGAATCTCCAATT-1 AKI3010018   979.1271  508          1.407835
# AKI3010018_AAACGAATCTTTCCAA-1 AKI3010018 11868.1713 3255          0.000000
# AKI3010018_AAACGCTAGCTTTCTT-1 AKI3010018  1177.9730  559         17.778361
#                               subclass.l2 subclass.l1 dataSource sampletype
# AKI3010018_AAACCCACAGGGATAC-1 dPT/DTL     PT          KPMP       AKI
# AKI3010018_AAACCCATCTGATGGT-1 EC-AEA      EC          KPMP       AKI
# AKI3010018_AAACCCATCTGCTTTA-1 dPT/DTL     PT          KPMP       AKI
# AKI3010018_AAACGAATCTCCAATT-1 T-CYT       Immune      KPMP       AKI
# AKI3010018_AAACGAATCTTTCCAA-1 aTAL2       ATL/TAL     KPMP       AKI
# ...

# %%
GetAssayData(object = file, slot = "counts")
# Out:
#    [[ suppressing 32 column names ‘AKI3010018_AAACCCACAGGGATAC-1’, ‘AKI3010018_AAACCCATCTGATGGT-1’, ‘AKI3010018_AAACCCATCTGCTTTA-1’ ... ]]
#
#    [[ suppressing 32 column names ‘AKI3010018_AAACCCACAGGGATAC-1’, ‘AKI3010018_AAACCCATCTGATGGT-1’, ‘AKI3010018_AAACCCATCTGCTTTA-1’ ... ]]
#
#    [[ suppressing 32 column names ‘AKI3010018_AAACCCACAGGGATAC-1’, ‘AKI3010018_AAACCCATCTGATGGT-1’, ‘AKI3010018_AAACCCATCTGCTTTA-1’ ... ]]
# 30395 x 110346 sparse Matrix of class "dgCMatrix"
#
# AL627309.1   .         .         .         .           .         .         .
# AL669831.5   .         .         .         .           .         .         .
# LINC00115    .         .         .         .           .         .         .
# FAM41C       .         .         .         .           .         .         .
# AL645608.1   .         .         .         .           .         .         .
# SAMD11       .         .         .         .           .         .         .
# ...
