# %%
#he et al. annotation
import os
os.chdir('/lustre/scratch117/cellgen/team297/bs16/current_projects/kidney_glomTI_response/code')
import anndata as ad
import scanpy as sc
import os
import pandas as pd
import numpy as np
import useful_functions as uf
import scvi
sc.set_figure_params(figsize=(6, 6))
import sys
print(sys.executable)
# Out:
# Global seed set to 0
# /home/jovyan/my-conda-envs/myenv/bin/python
# /home/jovyan/my-conda-envs/myenv/lib/python3.8/site-packages/pytorch_lightning/utilities/warnings.py:53: LightningDeprecationWarning: pytorch_lightning.utilities.warnings.rank_zero_deprecation has been deprecated in v1.6 and will be removed in v1.8. Use the equivalent function from the pytorch_lightning.utilities.rank_zero module instead.
#   new_rank_zero_deprecation(
# /home/jovyan/my-conda-envs/myenv/lib/python3.8/site-packages/pytorch_lightning/utilities/warnings.py:58: LightningDeprecationWarning: The `pytorch_lightning.loggers.base.rank_zero_experiment` is deprecated in v1.7 and will be removed in v1.9. Please use `pytorch_lightning.loggers.logger.rank_zero_experiment` instead.
#   return new_rank_zero_deprecation(*args, **kwargs)

# %%
import warnings
warnings.filterwarnings('ignore')
#this will hide the awful pandas deprec warnings that are currently plaguing scanpy

#now print versions
print(sc.__version__)
print(ad.__version__)
print(pd.__version__)
print(scvi.__version__)
os.chdir('/lustre/scratch117/cellgen/team297/bs16/current_projects/kidney_glomTI_response')
# Out:
# 1.9.1
# 0.8.0
# 1.4.3
# 0.19.0

# %%
adata = sc.read_h5ad("./data/public_data/he_2021/he_adata.h5ad")
adata.layers['counts'] = adata.X

# %%
sc.pp.log1p(adata)

# %%
sc.pp.pca(adata)
sc.pp.neighbors(adata)
sc.tl.umap(adata)

# %%
sc.tl.leiden(adata, resolution = 1.2)

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 766 × 16988
#     obs: 'UMAP1', 'UMAP2', 'CellType', 'MLC_subclusters', 'nGene', 'PlateInfo', 'NKG7', 'HAVCR1', 'MYRF', 'FSTL3', 'CCDC146', 'CFI', 'CD68', 'FCGR3B', 'VEGFA', 'NPHS2', 'ITGA8', 'KLRK1', 'CXCL6', 'VCAM1', 'PCK1', 'LYZ', 'CSF3R', 'MYO1D', 'SEMA3G', 'KDR', 'NES', 'LINC01320', 'CRB2', 'FCN1', 'TOX3', 'PLOD2', 'THSD7A', 'SLC44A4', 'GPC4', 'CLDN5', 'NCAM1', 'CNN1', 'EPHA7', 'C1orf186', 'DDN', 'GOLIM4', 'MMP7', 'PECAM1', 'SYNPO', 'MPP5', 'CD4', 'PTPRC', 'PDGFRB', 'PDGFRA', 'CD3D', 'NPR1', 'GATA3', 'TCF21', 'CDH2', 'PLCE1', 'ARHGAP40', 'TMEM204', 'VCAN', 'AQP2', 'TSPAN2', 'TMEM150C', 'ACTA2', 'UMOD', 'PAPLN', 'SULF1', 'LRRC48', 'ST3GAL6', 'KLRD1', 'PROM1', 'RNF128', 'KRT7', 'APLP1', 'S100P', 'PODXL', 'MS4A1', 'CDKN1C', 'LAMC2', 'FCGR3A', 'CLIC5', 'IGFBP5', 'CD3G', 'CD14', 'CLDN3', 'CD19', 'PRF1', 'EMCN', 'COL4A3', 'PDLIM2', 'CXCL12', 'EHD3', 'MGAT5', 'NPHS1', 'HLA.DRA', 'PTPRO', 'SEPT4', 'PVRL3', 'SPNS2', 'CD8A', 'leiden'
#     uns: 'log1p', 'pca', 'neighbors', 'umap', 'leiden'
#     obsm: 'X_pca', 'X_umap'
#     varm: 'PCs'
#     layers: 'counts'
#     obsp: 'distances', 'connectivities'

# %%
sc.pl.umap(adata, color = ['leiden', 'PlateInfo','CellType'] , legend_loc = 'on data')

# %%
adata.var['highly_variable'] = True
adata.var['Symbol'] = adata.var_names.values
markers = uf.get_markers(adata, 'leiden')
# Out:
# 100% |########################################################################|

# %%
markers['0'].head(10)
# Out:
#           GeneFrequency  GeneFrequencyGlobal  GeneExpressionInCluster  \
# Symbol
# SLC1A3         0.604938             0.142298                 2.027360
# SAP30          0.555556             0.133159                 2.250388
# HK2            0.654321             0.186684                 1.270816
# FMN1           0.506173             0.114883                 1.142247
# FCGR1B         0.580247             0.151436                 1.600191
# SH3PXD2B       0.469136             0.100522                 1.219562
# RNF175         0.543210             0.140992                 1.684214
# NCF1           0.728395             0.232376                 2.748099
# NCF1B          0.493827             0.124021                 0.922287
# HLA-DPB2       0.827160             0.301567                 1.987804
#
#           GeneExpressionOutsideCluster  GeneExpressionGlobal       idf  \
# Symbol
# SLC1A3                        0.106593              0.309703  1.949834
# SAP30                         0.199357              0.416242  2.016209
# HK2                           0.168977              0.285490  1.678338
# FMN1                          0.040493              0.156997  2.163845
# FCGR1B                        0.220431              0.366333  1.887592
# SH3PXD2B                      0.052702              0.176091  2.297377
# RNF175                        0.204563              0.361028  1.959051
# NCF1                          0.408296              0.655717  1.459399
# NCF1B                         0.162969              0.243263  2.087305
# HLA-DPB2                      0.479706              0.639178  1.198764
#
#              tfidf          pval     adj_pvals
# Symbol
# SLC1A3    1.179529  2.876000e-10  4.037222e-09
# SAP30     1.120116  1.403278e-14  2.056333e-13
# HK2       1.098171  8.183027e-05  1.074682e-03
# FMN1      1.095280  1.722270e-21  2.685188e-20
# FCGR1B    1.095269  6.673310e-11  9.432714e-10
# SH3PXD2B  1.077782  2.044404e-28  3.382391e-27
# RNF175    1.064176  1.666003e-14  2.440099e-13
# NCF1      1.063019  1.531830e-01  1.000000e+00
# NCF1B     1.030768  5.737939e-21  8.908764e-20
# HLA-DPB2  0.991571  9.958445e-01  1.000000e+00
